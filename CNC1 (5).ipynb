# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'experiment_17.csv', 'train.csv', 'experiment_09.csv', 'experiment_05.csv', 'experiment_02.csv', 'experiment_06.csv', 'experiment_15.csv', 'experiment_13.csv', 'experiment_11.csv', 'experiment_07.csv', 'experiment_10.csv', 'experiment_18.csv', 'experiment_03.csv', 'experiment_16.csv', 'experiment_01.csv', 'experiment_04.csv', 'experiment_14.csv', 'experiment_08.csv', 'experiment_12.csv', 'sample_data']

# %%
import numpy as np
import pandas as pd

df_train = pd.read_csv('train.csv')
print(df_train.shape)
print(df_train.sample(10))
# Out:
# (18, 7)
#     No material  feedrate  clamp_pressure tool_condition machining_finalized  \
# 9   10      wax        12             4.0           worn                 yes
# 12  13      wax         3             4.0           worn                 yes
# 0    1      wax         6             4.0         unworn                 yes
# 10  11      wax         3             4.0         unworn                 yes
# 5    6      wax         6             4.0           worn                 yes
# 11  12      wax         3             3.0         unworn                 yes
# 1    2      wax        20             4.0         unworn                 yes
# 14  15      wax         6             3.0           worn                 yes
# 7    8      wax        20             4.0           worn                 yes
# 13  14      wax         3             3.0           worn                 yes
#
#    passed_visual_inspection
# 9                        no
# 12                      yes
# 0                       yes
# 10                      yes
# 5                        no
# 11                      yes
# 1                       yes
# 14                      yes
# 7                        no
# 13                      yes

# %%
print(df_train['tool_condition'].unique())
# Out:
# ['unworn' 'worn']

# %%
# Description: Combine the train and experiment datasets into a single dataset

import numpy as np
import pandas as pd

# Load training dataset
df_train = pd.read_csv('train.csv')

# Dictionary to store experiment DataFrames
experiments = {}
total = 0

# Load experiment_01.csv to experiment_09.csv
for i in range(1, 10):
    filename = f'experiment_0{i}.csv'
    experiments[i] = pd.read_csv(filename)
    total += experiments[i].shape[0]
# experiments[i].shape[0] tell us number of rows in experiment 1

# Load experiment_10.csv to experiment_18.csv
for i in range(10, 19):
    filename = f'experiment_{i}.csv'
    experiments[i] = pd.read_csv(filename)
    total += experiments[i].shape[0]

print(f"Total rows across all experiments: {total}")

# Print shapes of all experiment datasets
for i in range(1, 19):
    print(f"df_{i} shape: {experiments[i].shape}")

########################
# Missing Value Handle #
########################

print("Missing values before handling:")
print(df_train.isnull().sum())
# .isnull().sum()) tell us hoe many null value in whole experiment


# Fill missing values
df_train['passed_visual_inspection'] = (
    df_train['passed_visual_inspection']
    .fillna('no')
)
print("\nMissing values after handling:")
print(df_train.isnull().sum())
# after write no to missing value check again missing values



##########################
# Combine all dataframes #
##########################

frames = []

for i in range(1, 19):

    df_exp = experiments[i].copy()

    # Add experiment information
    df_exp["exp_no"] = i
    df_exp["feedrate"] = float(df_train.loc[i - 1, "feedrate"])
    df_exp["clamp_pressure"] = df_train.loc[i - 1, "clamp_pressure"]

    # Add target label
    df_exp["target"] = (
        "worn"
        if df_train.loc[i - 1, "tool_condition"] == "worn"
        else "unworn"
    )

    frames.append(df_exp)

# Merge all experiments into one DataFrame
df = pd.concat(frames, axis=0, ignore_index=True)
#pd.concat()  Combines multiple DataFrames.

print("\nFirst 5 rows:")
print(df.head())

print("\nFinal Dataset Shape:")
print(df.shape)

################
# Save Dataset #
################

df.to_csv('aggregated.csv', index=False)

print("\nAggregated dataset saved successfully.")
# Out:
# Total rows across all experiments: 25286
# df_1 shape: (1055, 48)
# df_2 shape: (1668, 48)
# df_3 shape: (1521, 48)
# df_4 shape: (532, 48)
# df_5 shape: (462, 48)
# df_6 shape: (1296, 48)
# df_7 shape: (565, 48)
# df_8 shape: (605, 48)
# df_9 shape: (740, 48)
# df_10 shape: (1301, 48)
# df_11 shape: (2314, 48)
# df_12 shape: (2276, 48)
# df_13 shape: (2233, 48)
# df_14 shape: (2332, 48)
# df_15 shape: (1381, 48)
# df_16 shape: (602, 48)
# df_17 shape: (2150, 48)
# df_18 shape: (2253, 48)
# Missing values before handling:
# No                          0
# material                    0
# feedrate                    0
# clamp_pressure              0
# tool_condition              0
# machining_finalized         0
# passed_visual_inspection    4
# dtype: int64
#
# Missing values after handling:
# No                          0
# material                    0
# feedrate                    0
# clamp_pressure              0
# tool_condition              0
# machining_finalized         0
# passed_visual_inspection    0
# dtype: int64
#
# First 5 rows:
#    X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0              198.0                0.0                   0.00
# 1              198.0              -10.8                -350.00
# 2              196.0              -17.8                  -6.25
# 3              194.0              -18.0                   0.00
# 4              193.0              -17.9                 -18.80
#
#    X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0               198.0                 0.0                0.000000
# 1               198.0               -13.6             -358.000000
# 2               196.0               -17.9               -0.000095
# 3               194.0               -17.9               -0.000095
# 4               192.0               -17.9                0.000095
#
#    X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  X1_OutputVoltage  \
# 0                0.18           0.0207             329.0              2.77
# 1              -10.90           0.1860             328.0             23.30
# 2               -8.59           0.1400             328.0             30.60
# 3               -6.11           0.1300             327.0             30.30
# 4               -5.70           0.1140             328.0             30.50
#
#    ...  S1_OutputPower  S1_SystemInertia  M1_CURRENT_PROGRAM_NUMBER  \
# 0  ...    6.960000e-07              12.0                        1.0
# 1  ...   -5.270000e-07              12.0                        1.0
# 2  ...    9.100000e-07              12.0                        1.0
# 3  ...    1.070000e-06              12.0                        1.0
# 4  ...    1.960000e-06              12.0                        1.0
#
#    M1_sequence_number  M1_CURRENT_FEEDRATE  Machining_Process  exp_no  \
# 0                 0.0                 50.0           Starting       1
# 1                 4.0                 50.0               Prep       1
# 2                 7.0                 50.0               Prep       1
# 3                 7.0                 50.0               Prep       1
# 4                 7.0                 50.0               Prep       1
#
#    feedrate  clamp_pressure  target
# 0       6.0             4.0  unworn
# 1       6.0             4.0  unworn
# 2       6.0             4.0  unworn
# 3       6.0             4.0  unworn
# 4       6.0             4.0  unworn
#
# [5 rows x 52 columns]
#
# Final Dataset Shape:
# (25286, 52)
#
# Aggregated dataset saved successfully.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the aggregated dataset
df = pd.read_csv("aggregated.csv")


# ==========================================================
# 1. BASIC INFORMATION ABOUT DATASET
# ==========================================================

#PRINT STARTING 5 ROWS
print(df.head())

#PRINT LAST 5 ROWS
print(df.tail())

#SHAPE (NO. OF ROWS, NO OF COLUMNS)
print(df.shape)

#NAME OF COLMNS
print(df.columns.tolist())

#DATATYPE
print(df.dtypes)

#INFORMATION
print(df.info())
# Out:
#    X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0              198.0                0.0                   0.00
# 1              198.0              -10.8                -350.00
# 2              196.0              -17.8                  -6.25
# 3              194.0              -18.0                   0.00
# 4              193.0              -17.9                 -18.80
#
#    X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0               198.0                 0.0                0.000000
# 1               198.0               -13.6             -358.000000
# 2               196.0               -17.9               -0.000095
# 3               194.0               -17.9               -0.000095
# 4               192.0               -17.9                0.000095
#
#    X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  X1_OutputVoltage  \
# 0                0.18           0.0207             329.0              2.77
# 1              -10.90           0.1860             328.0             23.30
# 2               -8.59           0.1400             328.0             30.60
# 3               -6.11           0.1300             327.0             30.30
# 4               -5.70           0.1140             328.0             30.50
#
#    ...  S1_OutputPower  S1_SystemInertia  M1_CURRENT_PROGRAM_NUMBER  \
# 0  ...    6.960000e-07              12.0                        1.0
# 1  ...   -5.270000e-07              12.0                        1.0
# 2  ...    9.100000e-07              12.0                        1.0
# 3  ...    1.070000e-06              12.0                        1.0
# 4  ...    1.960000e-06              12.0                        1.0
#
#    M1_sequence_number  M1_CURRENT_FEEDRATE  Machining_Process  exp_no  \
# 0                 0.0                 50.0           Starting       1
# 1                 4.0                 50.0               Prep       1
# 2                 7.0                 50.0               Prep       1
# 3                 7.0                 50.0               Prep       1
# 4                 7.0                 50.0               Prep       1
#
#    feedrate  clamp_pressure  target
# 0       6.0             4.0  unworn
# 1       6.0             4.0  unworn
# 2       6.0             4.0  unworn
# 3       6.0             4.0  unworn
# 4       6.0             4.0  unworn
#
# [5 rows x 52 columns]
#        X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 25281              144.0              -2.30                  100.0
# 25282              144.0              -2.47                   25.0
# 25283              143.0              -2.20                   81.2
# 25284              143.0              -2.05                   68.7
# 25285              143.0              -2.15                  -68.7
#
#        X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 25281               144.0               -2.57                   0.977
# 25282               144.0               -2.46                   1.080
# 25283               143.0               -2.35                   1.170
# 25284               143.0               -2.23                   1.260
# 25285               143.0               -2.09                   1.350
#
#        X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  \
# 25281               -5.05           0.0732             327.0
# 25282               -5.62           0.0996             327.0
# 25283               -4.42           0.0539             327.0
# 25284               -5.83           0.0809             327.0
# 25285               -4.37           0.0857             327.0
#
#        X1_OutputVoltage  ...  S1_OutputPower  S1_SystemInertia  \
# 25281              9.56  ...           0.158              12.0
# 25282             10.30  ...           0.187              12.0
# 25283              7.79  ...           0.182              12.0
# 25284              8.32  ...           0.182              12.0
# 25285              8.01  ...           0.191              12.0
#
#        M1_CURRENT_PROGRAM_NUMBER  M1_sequence_number  M1_CURRENT_FEEDRATE  \
# 25281                        1.0                57.0                  3.0
# 25282                        1.0                57.0                  3.0
# 25283                        1.0                57.0                  3.0
# 25284                        1.0                57.0                  3.0
# 25285                        1.0                57.0                  3.0
#
#        Machining_Process  exp_no  feedrate  clamp_pressure  target
# 25281                End      18       3.0             2.5    worn
# 25282                End      18       3.0             2.5    worn
# 25283                End      18       3.0             2.5    worn
# 25284                End      18       3.0             2.5    worn
# 25285                End      18       3.0             2.5    worn
#
# [5 rows x 52 columns]
# (25286, 52)
# ['X1_ActualPosition', 'X1_ActualVelocity', 'X1_ActualAcceleration', 'X1_CommandPosition', 'X1_CommandVelocity', 'X1_CommandAcceleration', 'X1_CurrentFeedback', 'X1_DCBusVoltage', 'X1_OutputCurrent', 'X1_OutputVoltage', 'X1_OutputPower', 'Y1_ActualPosition', 'Y1_ActualVelocity', 'Y1_ActualAcceleration', 'Y1_CommandPosition', 'Y1_CommandVelocity', 'Y1_CommandAcceleration', 'Y1_CurrentFeedback', 'Y1_DCBusVoltage', 'Y1_OutputCurrent', 'Y1_OutputVoltage', 'Y1_OutputPower', 'Z1_ActualPosition', 'Z1_ActualVelocity', 'Z1_ActualAcceleration', 'Z1_CommandPosition', 'Z1_CommandVelocity', 'Z1_CommandAcceleration', 'Z1_CurrentFeedback', 'Z1_DCBusVoltage', 'Z1_OutputCurrent', 'Z1_OutputVoltage', 'S1_ActualPosition', 'S1_ActualVelocity', 'S1_ActualAcceleration', 'S1_CommandPosition', 'S1_CommandVelocity', 'S1_CommandAcceleration', 'S1_CurrentFeedback', 'S1_DCBusVoltage', 'S1_OutputCurrent', 'S1_OutputVoltage', 'S1_OutputPower', 'S1_SystemInertia', 'M1_CURRENT_PROGRAM_NUMBER', 'M1_sequence_number', 'M1_CURRENT_FEEDRATE', 'Machining_Process', 'exp_no', 'feedrate', 'clamp_pressure', 'target']
# X1_ActualPosition            float64
# X1_ActualVelocity            float64
# X1_ActualAcceleration        float64
# X1_CommandPosition           float64
# X1_CommandVelocity           float64
# X1_CommandAcceleration       float64
# X1_CurrentFeedback           float64
# X1_DCBusVoltage              float64
# X1_OutputCurrent             float64
# X1_OutputVoltage             float64
# X1_OutputPower               float64
# Y1_ActualPosition            float64
# Y1_ActualVelocity            float64
# Y1_ActualAcceleration        float64
# Y1_CommandPosition           float64
# Y1_CommandVelocity           float64
# Y1_CommandAcceleration       float64
# Y1_CurrentFeedback           float64
# Y1_DCBusVoltage              float64
# Y1_OutputCurrent             float64
# Y1_OutputVoltage             float64
# Y1_OutputPower               float64
# Z1_ActualPosition            float64
# Z1_ActualVelocity            float64
# Z1_ActualAcceleration        float64
# Z1_CommandPosition           float64
# Z1_CommandVelocity           float64
# Z1_CommandAcceleration       float64
# Z1_CurrentFeedback           float64
# Z1_DCBusVoltage              float64
# Z1_OutputCurrent             float64
# Z1_OutputVoltage             float64
# S1_ActualPosition            float64
# S1_ActualVelocity            float64
# S1_ActualAcceleration        float64
# S1_CommandPosition           float64
# S1_CommandVelocity           float64
# S1_CommandAcceleration       float64
# S1_CurrentFeedback           float64
# S1_DCBusVoltage              float64
# S1_OutputCurrent             float64
# S1_OutputVoltage             float64
# S1_OutputPower               float64
# S1_SystemInertia             float64
# M1_CURRENT_PROGRAM_NUMBER    float64
# M1_sequence_number           float64
# M1_CURRENT_FEEDRATE          float64
# Machining_Process             object
# exp_no                         int64
# feedrate                     float64
# clamp_pressure               float64
# target                        object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25286 entries, 0 to 25285
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   X1_ActualPosition          25286 non-null  float64
#  1   X1_ActualVelocity          25286 non-null  float64
#  2   X1_ActualAcceleration      25286 non-null  float64
#  3   X1_CommandPosition         25286 non-null  float64
#  4   X1_CommandVelocity         25286 non-null  float64
#  5   X1_CommandAcceleration     25286 non-null  float64
#  6   X1_CurrentFeedback         25286 non-null  float64
#  7   X1_DCBusVoltage            25286 non-null  float64
#  8   X1_OutputCurrent           25286 non-null  float64
#  9   X1_OutputVoltage           25286 non-null  float64
#  10  X1_OutputPower             25286 non-null  float64
#  11  Y1_ActualPosition          25286 non-null  float64
#  12  Y1_ActualVelocity          25286 non-null  float64
#  13  Y1_ActualAcceleration      25286 non-null  float64
#  14  Y1_CommandPosition         25286 non-null  float64
#  15  Y1_CommandVelocity         25286 non-null  float64
#  16  Y1_CommandAcceleration     25286 non-null  float64
#  17  Y1_CurrentFeedback         25286 non-null  float64
#  18  Y1_DCBusVoltage            25286 non-null  float64
#  19  Y1_OutputCurrent           25286 non-null  float64
#  20  Y1_OutputVoltage           25286 non-null  float64
#  21  Y1_OutputPower             25286 non-null  float64
#  22  Z1_ActualPosition          25286 non-null  float64
#  23  Z1_ActualVelocity          25286 non-null  float64
#  24  Z1_ActualAcceleration      25286 non-null  float64
#  25  Z1_CommandPosition         25286 non-null  float64
#  26  Z1_CommandVelocity         25286 non-null  float64
#  27  Z1_CommandAcceleration     25286 non-null  float64
#  28  Z1_CurrentFeedback         25286 non-null  float64
#  29  Z1_DCBusVoltage            25286 non-null  float64
#  30  Z1_OutputCurrent           25286 non-null  float64
#  31  Z1_OutputVoltage           25286 non-null  float64
#  32  S1_ActualPosition          25286 non-null  float64
#  33  S1_ActualVelocity          25286 non-null  float64
#  34  S1_ActualAcceleration      25286 non-null  float64
#  35  S1_CommandPosition         25286 non-null  float64
#  36  S1_CommandVelocity         25286 non-null  float64
#  37  S1_CommandAcceleration     25286 non-null  float64
#  38  S1_CurrentFeedback         25286 non-null  float64
#  39  S1_DCBusVoltage            25286 non-null  float64
#  40  S1_OutputCurrent           25286 non-null  float64
#  41  S1_OutputVoltage           25286 non-null  float64
#  42  S1_OutputPower             25286 non-null  float64
#  43  S1_SystemInertia           25286 non-null  float64
#  44  M1_CURRENT_PROGRAM_NUMBER  25286 non-null  float64
#  45  M1_sequence_number         25286 non-null  float64
#  46  M1_CURRENT_FEEDRATE        25286 non-null  float64
#  47  Machining_Process          25286 non-null  object
#  48  exp_no                     25286 non-null  int64
#  49  feedrate                   25286 non-null  float64
#  50  clamp_pressure             25286 non-null  float64
#  51  target                     25286 non-null  object
# dtypes: float64(49), int64(1), object(2)
# memory usage: 10.0+ MB
# None

# %%
# ==========================================================
# 2. CHECK MISSING VALUES
# ==========================================================


missing_values = df.isnull().sum()

#print columns along with there missing values
print(missing_values)

#total missing values
print(missing_values.sum())
# Out:
# X1_ActualPosition            0
# X1_ActualVelocity            0
# X1_ActualAcceleration        0
# X1_CommandPosition           0
# X1_CommandVelocity           0
# X1_CommandAcceleration       0
# X1_CurrentFeedback           0
# X1_DCBusVoltage              0
# X1_OutputCurrent             0
# X1_OutputVoltage             0
# X1_OutputPower               0
# Y1_ActualPosition            0
# Y1_ActualVelocity            0
# Y1_ActualAcceleration        0
# Y1_CommandPosition           0
# Y1_CommandVelocity           0
# Y1_CommandAcceleration       0
# Y1_CurrentFeedback           0
# Y1_DCBusVoltage              0
# Y1_OutputCurrent             0
# Y1_OutputVoltage             0
# Y1_OutputPower               0
# Z1_ActualPosition            0
# Z1_ActualVelocity            0
# Z1_ActualAcceleration        0
# Z1_CommandPosition           0
# Z1_CommandVelocity           0
# Z1_CommandAcceleration       0
# Z1_CurrentFeedback           0
# Z1_DCBusVoltage              0
# Z1_OutputCurrent             0
# Z1_OutputVoltage             0
# S1_ActualPosition            0
# S1_ActualVelocity            0
# S1_ActualAcceleration        0
# S1_CommandPosition           0
# S1_CommandVelocity           0
# S1_CommandAcceleration       0
# S1_CurrentFeedback           0
# S1_DCBusVoltage              0
# S1_OutputCurrent             0
# S1_OutputVoltage             0
# S1_OutputPower               0
# S1_SystemInertia             0
# M1_CURRENT_PROGRAM_NUMBER    0
# M1_sequence_number           0
# M1_CURRENT_FEEDRATE          0
# Machining_Process            0
# exp_no                       0
# feedrate                     0
# clamp_pressure               0
# target                       0
# dtype: int64
# 0

# %%
# ==========================================================
# 3. CHECK DUPLICATE ROWS
# ==========================================================

duplicates = df.duplicated().sum()

print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 331

# %%
# ==========================================================
# 4. TARGET VARIABLE ANALYSIS
# ==========================================================


#print target count like no of worn and unworn
print("\nTarget values:")
print(df["target"].value_counts())


# calculate percentage of target
print("\nTarget percentages:")
print(df["target"].value_counts(normalize=True) * 100)


# Plot target distribution

plt.figure(figsize=(6, 4))

df["target"].value_counts().plot(kind="bar")

plt.title("Distribution of Tool Condition")
plt.xlabel("Tool Condition")
plt.ylabel("Number of Samples")

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Target values:
# target
# worn      13308
# unworn    11978
# Name: count, dtype: int64
#
# Target percentages:
# target
# worn      52.629914
# unworn    47.370086
# Name: proportion, dtype: float64

# %%
# ==========================================================
# 5. EXPERIMENT ANALYSIS
# ==========================================================

print("\nNumber of samples in each experiment:")

#value_counts() counts how many times each unique value appears in a column
#and sort according to exp. number .
experiment_counts = df["exp_no"].value_counts().sort_index()
print(experiment_counts)


# Target associated with each experiment

print("\nTool condition for each experiment:")
# group of target value (worn/unworn ) and Take the first value from each group.
experiment_target = df.groupby("exp_no")["target"].first()

print(experiment_target)
# Out:
# Number of samples in each experiment:
# exp_no
# 1     1055
# 2     1668
# 3     1521
# 4      532
# 5      462
# 6     1296
# 7      565
# 8      605
# 9      740
# 10    1301
# 11    2314
# 12    2276
# 13    2233
# 14    2332
# 15    1381
# 16     602
# 17    2150
# 18    2253
# Name: count, dtype: int64
#
# Tool condition for each experiment:
# exp_no
# 1     unworn
# 2     unworn
# 3     unworn
# 4     unworn
# 5     unworn
# 6       worn
# 7       worn
# 8       worn
# 9       worn
# 10      worn
# 11    unworn
# 12    unworn
# 13      worn
# 14      worn
# 15      worn
# 16      worn
# 17    unworn
# 18      worn
# Name: target, dtype: object

# %%
# ==========================================================
# 6. STATISTICAL SUMMARY
# ==========================================================

print(df.describe())
# Out:
#        X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# count       25286.000000       25286.000000           25286.000000
# mean          159.052045          -0.288657               0.094264
# std            19.330873           5.658260              93.877623
# min           141.000000         -20.400000           -1280.000000
# 25%           145.000000          -2.050000             -31.300000
# 50%           153.000000           0.000000               0.000000
# 75%           162.000000           0.200000              25.000000
# max           198.000000          50.700000            1440.000000
#
#        X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# count        25286.000000        25286.000000            25286.000000
# mean           159.050700           -0.283076                0.253215
# std             19.331144            5.664309               72.594951
# min            141.000000          -20.000000            -1000.000000
# 25%            145.000000           -2.050000                0.000000
# 50%            153.000000            0.000000                0.000000
# 75%            162.000000            0.000000                0.000000
# max            198.000000           50.000000             1000.000000
#
#        X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  \
# count        25286.000000     2.528600e+04      25286.000000
# mean            -0.469714     6.603073e-02        326.945859
# std              4.220750     3.700384e-02          1.459937
# min            -23.400000     2.780000e-19        320.000000
# 25%             -3.930000     4.150000e-02        326.000000
# 50%             -0.666000     6.680000e-02        327.000000
# 75%              3.140000     9.130000e-02        327.000000
# max             27.100000     3.800000e-01        331.000000
#
#        X1_OutputVoltage  ...  S1_OutputCurrent  S1_OutputVoltage  \
# count      25286.000000  ...      25286.000000      25286.000000
# mean           7.986942  ...        322.784505         85.479195
# std            7.710379  ...          4.293571         52.531863
# min            0.000000  ...        290.000000          0.000000
# 25%            2.590000  ...        320.000000          0.000000
# 50%            7.140000  ...        322.000000        117.000000
# 75%           10.200000  ...        327.000000        119.000000
# max           75.400000  ...        332.000000        130.000000
#
#        S1_OutputPower  S1_SystemInertia  M1_CURRENT_PROGRAM_NUMBER  \
# count    25286.000000           25286.0               25286.000000
# mean         0.127405              12.0                   1.003441
# std          0.080753               0.0                   0.349055
# min         -0.002960              12.0                   0.000000
# 25%          0.000005              12.0                   1.000000
# 50%          0.164000              12.0                   1.000000
# 75%          0.183000              12.0                   1.000000
# max          0.569000              12.0                   4.000000
#
#        M1_sequence_number  M1_CURRENT_FEEDRATE        exp_no      feedrate  \
# count        25286.000000         25286.000000  25286.000000  25286.000000
# mean            47.345013            16.542039     10.738235      7.123942
# std             43.826214            19.620219      5.213285      6.167036
# min              0.000000             3.000000      1.000000      3.000000
# 25%              2.000000             3.000000      6.000000      3.000000
# 50%             39.000000             6.000000     12.000000      3.000000
# 75%             85.000000            20.000000     15.000000      6.000000
# max            135.000000            50.000000     18.000000     20.000000
#
#        clamp_pressure
# count    25286.000000
# mean         3.368168
# std          0.615639
# min          2.500000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          4.000000
#
# [8 rows x 50 columns]

# %%
# ==========================================================
# 7. NUMERICAL COLUMNS
# ==========================================================

numeric_columns = df.select_dtypes(
    include=np.number
).columns.tolist()

print("Numerical columns:")
print(numeric_columns)
# Out:
# Numerical columns:
# ['X1_ActualPosition', 'X1_ActualVelocity', 'X1_ActualAcceleration', 'X1_CommandPosition', 'X1_CommandVelocity', 'X1_CommandAcceleration', 'X1_CurrentFeedback', 'X1_DCBusVoltage', 'X1_OutputCurrent', 'X1_OutputVoltage', 'X1_OutputPower', 'Y1_ActualPosition', 'Y1_ActualVelocity', 'Y1_ActualAcceleration', 'Y1_CommandPosition', 'Y1_CommandVelocity', 'Y1_CommandAcceleration', 'Y1_CurrentFeedback', 'Y1_DCBusVoltage', 'Y1_OutputCurrent', 'Y1_OutputVoltage', 'Y1_OutputPower', 'Z1_ActualPosition', 'Z1_ActualVelocity', 'Z1_ActualAcceleration', 'Z1_CommandPosition', 'Z1_CommandVelocity', 'Z1_CommandAcceleration', 'Z1_CurrentFeedback', 'Z1_DCBusVoltage', 'Z1_OutputCurrent', 'Z1_OutputVoltage', 'S1_ActualPosition', 'S1_ActualVelocity', 'S1_ActualAcceleration', 'S1_CommandPosition', 'S1_CommandVelocity', 'S1_CommandAcceleration', 'S1_CurrentFeedback', 'S1_DCBusVoltage', 'S1_OutputCurrent', 'S1_OutputVoltage', 'S1_OutputPower', 'S1_SystemInertia', 'M1_CURRENT_PROGRAM_NUMBER', 'M1_sequence_number', 'M1_CURRENT_FEEDRATE', 'exp_no', 'feedrate', 'clamp_pressure']

# %%
# ==========================================================
# 8. CATEGORICAL COLUMNS
# ==========================================================

categorical_columns = df.select_dtypes(
    include=["object", "category"]
).columns.tolist()

print("Categorical columns:")
print(categorical_columns)
# Out:
# Categorical columns:
# ['Machining_Process', 'target']

# %%
# ==========================================================
# 9. UNIQUE VALUES
# ==========================================================

for column in df.columns:

    print("\nColumn:", column)

    print("Number of unique values:",
          df[column].nunique())
# Out:
# Column: X1_ActualPosition
# Number of unique values: 58
#
# Column: X1_ActualVelocity
# Number of unique values: 830
#
# Column: X1_ActualAcceleration
# Number of unique values: 259
#
# Column: X1_CommandPosition
# Number of unique values: 58
#
# Column: X1_CommandVelocity
# Number of unique values: 1739
#
# Column: X1_CommandAcceleration
# Number of unique values: 2296
#
# Column: X1_CurrentFeedback
# Number of unique values: 2386
#
# Column: X1_DCBusVoltage
# Number of unique values: 1042
#
# Column: X1_OutputCurrent
# Number of unique values: 12
#
# Column: X1_OutputVoltage
# Number of unique values: 1831
#
# Column: X1_OutputPower
# Number of unique values: 4835
#
# Column: Y1_ActualPosition
# Number of unique values: 335
#
# Column: Y1_ActualVelocity
# Number of unique values: 859
#
# Column: Y1_ActualAcceleration
# Number of unique values: 264
#
# Column: Y1_CommandPosition
# Number of unique values: 335
#
# Column: Y1_CommandVelocity
# Number of unique values: 1786
#
# Column: Y1_CommandAcceleration
# Number of unique values: 2245
#
# Column: Y1_CurrentFeedback
# Number of unique values: 3027
#
# Column: Y1_DCBusVoltage
# Number of unique values: 1084
#
# Column: Y1_OutputCurrent
# Number of unique values: 15
#
# Column: Y1_OutputVoltage
# Number of unique values: 2044
#
# Column: Y1_OutputPower
# Number of unique values: 5706
#
# Column: Z1_ActualPosition
# Number of unique values: 474
#
# Column: Z1_ActualVelocity
# Number of unique values: 244
#
# Column: Z1_ActualAcceleration
# Number of unique values: 177
#
# Column: Z1_CommandPosition
# Number of unique values: 484
#
# Column: Z1_CommandVelocity
# Number of unique values: 74
#
# Column: Z1_CommandAcceleration
# Number of unique values: 31
#
# Column: Z1_CurrentFeedback
# Number of unique values: 1
#
# Column: Z1_DCBusVoltage
# Number of unique values: 1
#
# Column: Z1_OutputCurrent
# Number of unique values: 1
#
# Column: Z1_OutputVoltage
# Number of unique values: 1
#
# Column: S1_ActualPosition
# Number of unique values: 2798
#
# Column: S1_ActualVelocity
# Number of unique values: 368
#
# Column: S1_ActualAcceleration
# Number of unique values: 1937
#
# Column: S1_CommandPosition
# Number of unique values: 2779
#
# Column: S1_CommandVelocity
# Number of unique values: 75
#
# Column: S1_CommandAcceleration
# Number of unique values: 5
#
# Column: S1_CurrentFeedback
# Number of unique values: 1300
#
# Column: S1_DCBusVoltage
# Number of unique values: 480
#
# Column: S1_OutputCurrent
# Number of unique values: 38
#
# Column: S1_OutputVoltage
# Number of unique values: 125
#
# Column: S1_OutputPower
# Number of unique values: 2228
#
# Column: S1_SystemInertia
# Number of unique values: 1
#
# Column: M1_CURRENT_PROGRAM_NUMBER
# Number of unique values: 3
#
# Column: M1_sequence_number
# Number of unique values: 135
#
# Column: M1_CURRENT_FEEDRATE
# Number of unique values: 6
#
# Column: Machining_Process
# Number of unique values: 11
#
# Column: exp_no
# Number of unique values: 18
#
# Column: feedrate
# Number of unique values: 5
#
# Column: clamp_pressure
# Number of unique values: 3
#
# Column: target
# Number of unique values: 2

# %%
# ==========================================================
# 10. ANALYZE FEEDRATE
# ==========================================================

print("\nFeedrate statistics:")
print(df["feedrate"].describe())

print("\nFeedrate by target:")
print(
    df.groupby("target")["feedrate"].describe()
)
# Out:
# Feedrate statistics:
# count    25286.000000
# mean         7.123942
# std          6.167036
# min          3.000000
# 25%          3.000000
# 50%          3.000000
# 75%          6.000000
# max         20.000000
# Name: feedrate, dtype: float64
#
# Feedrate by target:
#           count      mean       std  min  25%  50%   75%   max
# target
# unworn  11978.0  6.801469  6.267305  3.0  3.0  3.0   6.0  20.0
# worn    13308.0  7.414187  6.060955  3.0  3.0  3.0  12.0  20.0

# %%
# ==========================================================
# 11. ANALYZE CLAMP PRESSURE
# ==========================================================

print("\nClamp pressure statistics:")
print(df["clamp_pressure"].describe())

print("\nClamp pressure by target:")
print(
    df.groupby("target")["clamp_pressure"].describe()
)
# Out:
# Clamp pressure statistics:
# count    25286.000000
# mean         3.368168
# std          0.615639
# min          2.500000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          4.000000
# Name: clamp_pressure, dtype: float64
#
# Clamp pressure by target:
#           count      mean       std  min  25%  50%  75%  max
# target
# unworn  11978.0  3.308566  0.617509  2.5  3.0  3.0  4.0  4.0
# worn    13308.0  3.421814  0.609005  2.5  3.0  4.0  4.0  4.0

# %%
# Features: 52
# Observations: 25286

#############
### Notes Based on (9. Unique Values) ###
#############

### 1. The dataset is combined.csv from train and experiment datasets
### 2. Convert TARGET to binary (0,1) --> 0: Unworn, 1: Worn
### 3. Drop list:
# 'MACHINING_PROCESS' -->  Not sure what it is and how it is related to the target
# 'Z1_CURRENTFEEDBACK', --> All same - 0.0
# 'Z1_DCBUSVOLTAGE', --> All same - 0.0
# 'Z1_OUTPUTCURRENT', --> All same - 0.0
# 'Z1_OUTPUTVOLTAGE', --> All same - 0.0
# 'S1_COMMANDACCELERATION' --> Actual value is 'S1_ACTUALPOSITION' is there, no need to command
# 'S1_SYSTEMINERTIA' --> All same - 12.0
# 'M1_CURRENT_PROGRAM_NUMBER' --> There is miss leading information all should be 1
# 'M1_SEQUENCE_NUMBER' --> There is miss leading information all should be 1
# 'M1_CURRENT_FEEDRATE' --> There is miss leading information, correct one is 'FEEDRATE'
# 'EXP_NO' --> Experiment number is not needed, it is cardinal variable

### 4. List should convert to numeric:
# 'FEEDRATE'
# 'CLAMP_PRESSURE'

# %%
# Notes Implementation
df.columns = df.columns.str.upper()

df = df.drop("EXP_NO", axis=1) # Drop EXP_NO column


df["TARGET"] = df["TARGET"].apply(lambda x: 1 if x == "worn" else 0) # Convert to binary

"""
###drop_list = ['MACHINING_PROCESS', 'Z1_CURRENTFEEDBACK', 'Z1_DCBUSVOLTAGE',
             'Z1_OUTPUTCURRENT', 'Z1_OUTPUTVOLTAGE', 'S1_COMMANDACCELERATION',
             'S1_SYSTEMINERTIA', 'M1_CURRENT_PROGRAM_NUMBER', 'M1_SEQUENCE_NUMBER',
             'M1_CURRENT_FEEDRATE', "EXP_NO", "Z1_COMMANDVELOCITY", "Z1_COMMANDACCELERATION"]"

###df.drop(drop_list, axis=1, inplace=True)"""

cat_to_numeric = ['FEEDRATE', 'CLAMP_PRESSURE',
                  'Z1_COMMANDVELOCITY', 'Z1_COMMANDACCELERATION',
                  'Z1_CURRENTFEEDBACK', 'Z1_DCBUSVOLTAGE',
                  'Z1_OUTPUTCURRENT', 'Z1_OUTPUTVOLTAGE', 'S1_COMMANDACCELERATION',
                  'S1_SYSTEMINERTIA','M1_CURRENT_FEEDRATE'] # Convert to numeric

# %%
##########################
#EDA
########

# %%
# 1. General Picture of the Dataset
def check_df(dataframe, head=5):
    print("##################### Shape #####################")
    print(dataframe.shape)
    print("##################### Types #####################")
    print(dataframe.dtypes)
    print("##################### Head #####################")
    print(dataframe.head(head))
    print("##################### Tail #####################")
    print(dataframe.tail(head))
    print("##################### NA #####################")
    print(dataframe.isnull().sum())
    print("##################### Quantiles #####################")
    print(dataframe.select_dtypes(include=np.number).quantile([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

check_df(df)
# Out:
# ##################### Shape #####################
# (25286, 51)
# ##################### Types #####################
# X1_ACTUALPOSITION            float64
# X1_ACTUALVELOCITY            float64
# X1_ACTUALACCELERATION        float64
# X1_COMMANDPOSITION           float64
# X1_COMMANDVELOCITY           float64
# X1_COMMANDACCELERATION       float64
# X1_CURRENTFEEDBACK           float64
# X1_DCBUSVOLTAGE              float64
# X1_OUTPUTCURRENT             float64
# X1_OUTPUTVOLTAGE             float64
# X1_OUTPUTPOWER               float64
# Y1_ACTUALPOSITION            float64
# Y1_ACTUALVELOCITY            float64
# Y1_ACTUALACCELERATION        float64
# Y1_COMMANDPOSITION           float64
# Y1_COMMANDVELOCITY           float64
# Y1_COMMANDACCELERATION       float64
# Y1_CURRENTFEEDBACK           float64
# Y1_DCBUSVOLTAGE              float64
# Y1_OUTPUTCURRENT             float64
# Y1_OUTPUTVOLTAGE             float64
# Y1_OUTPUTPOWER               float64
# Z1_ACTUALPOSITION            float64
# Z1_ACTUALVELOCITY            float64
# Z1_ACTUALACCELERATION        float64
# Z1_COMMANDPOSITION           float64
# Z1_COMMANDVELOCITY           float64
# Z1_COMMANDACCELERATION       float64
# Z1_CURRENTFEEDBACK           float64
# Z1_DCBUSVOLTAGE              float64
# Z1_OUTPUTCURRENT             float64
# Z1_OUTPUTVOLTAGE             float64
# S1_ACTUALPOSITION            float64
# S1_ACTUALVELOCITY            float64
# S1_ACTUALACCELERATION        float64
# S1_COMMANDPOSITION           float64
# S1_COMMANDVELOCITY           float64
# S1_COMMANDACCELERATION       float64
# S1_CURRENTFEEDBACK           float64
# S1_DCBUSVOLTAGE              float64
# S1_OUTPUTCURRENT             float64
# S1_OUTPUTVOLTAGE             float64
# S1_OUTPUTPOWER               float64
# S1_SYSTEMINERTIA             float64
# M1_CURRENT_PROGRAM_NUMBER    float64
# M1_SEQUENCE_NUMBER           float64
# M1_CURRENT_FEEDRATE          float64
# MACHINING_PROCESS             object
# FEEDRATE                     float64
# CLAMP_PRESSURE               float64
# TARGET                         int64
# dtype: object
# ##################### Head #####################
#    X1_ACTUALPOSITION  X1_ACTUALVELOCITY  X1_ACTUALACCELERATION  \
# 0              198.0                0.0                   0.00
# 1              198.0              -10.8                -350.00
# 2              196.0              -17.8                  -6.25
# 3              194.0              -18.0                   0.00
# 4              193.0              -17.9                 -18.80
#
#    X1_COMMANDPOSITION  X1_COMMANDVELOCITY  X1_COMMANDACCELERATION  \
# 0               198.0                 0.0                0.000000
# 1               198.0               -13.6             -358.000000
# 2               196.0               -17.9               -0.000095
# 3               194.0               -17.9               -0.000095
# 4               192.0               -17.9                0.000095
#
#    X1_CURRENTFEEDBACK  X1_DCBUSVOLTAGE  X1_OUTPUTCURRENT  X1_OUTPUTVOLTAGE  \
# 0                0.18           0.0207             329.0              2.77
# 1              -10.90           0.1860             328.0             23.30
# 2               -8.59           0.1400             328.0             30.60
# 3               -6.11           0.1300             327.0             30.30
# 4               -5.70           0.1140             328.0             30.50
#
#    ...  S1_OUTPUTVOLTAGE  S1_OUTPUTPOWER  S1_SYSTEMINERTIA  \
# 0  ...               0.0    6.960000e-07              12.0
# 1  ...               0.0   -5.270000e-07              12.0
# 2  ...               0.0    9.100000e-07              12.0
# 3  ...               0.0    1.070000e-06              12.0
# 4  ...               0.0    1.960000e-06              12.0
#
#    M1_CURRENT_PROGRAM_NUMBER  M1_SEQUENCE_NUMBER  M1_CURRENT_FEEDRATE  \
# 0                        1.0                 0.0                 50.0
# 1                        1.0                 4.0                 50.0
# 2                        1.0                 7.0                 50.0
# 3                        1.0                 7.0                 50.0
# 4                        1.0                 7.0                 50.0
#
#    MACHINING_PROCESS  FEEDRATE  CLAMP_PRESSURE  TARGET
# 0           Starting       6.0             4.0       0
# 1               Prep       6.0             4.0       0
# 2               Prep       6.0             4.0       0
# 3               Prep       6.0             4.0       0
# 4               Prep       6.0             4.0       0
#
# [5 rows x 51 columns]
# ##################### Tail #####################
#        X1_ACTUALPOSITION  X1_ACTUALVELOCITY  X1_ACTUALACCELERATION  \
# 25281              144.0              -2.30                  100.0
# 25282              144.0              -2.47                   25.0
# 25283              143.0              -2.20                   81.2
# 25284              143.0              -2.05                   68.7
# 25285              143.0              -2.15                  -68.7
#
#        X1_COMMANDPOSITION  X1_COMMANDVELOCITY  X1_COMMANDACCELERATION  \
# 25281               144.0               -2.57                   0.977
# 25282               144.0               -2.46                   1.080
# 25283               143.0               -2.35                   1.170
# 25284               143.0               -2.23                   1.260
# 25285               143.0               -2.09                   1.350
#
#        X1_CURRENTFEEDBACK  X1_DCBUSVOLTAGE  X1_OUTPUTCURRENT  \
# 25281               -5.05           0.0732             327.0
# 25282               -5.62           0.0996             327.0
# 25283               -4.42           0.0539             327.0
# 25284               -5.83           0.0809             327.0
# 25285               -4.37           0.0857             327.0
#
#        X1_OUTPUTVOLTAGE  ...  S1_OUTPUTVOLTAGE  S1_OUTPUTPOWER  \
# 25281              9.56  ...             118.0           0.158
# 25282             10.30  ...             119.0           0.187
# 25283              7.79  ...             119.0           0.182
# 25284              8.32  ...             118.0           0.182
# 25285              8.01  ...             119.0           0.191
#
#        S1_SYSTEMINERTIA  M1_CURRENT_PROGRAM_NUMBER  M1_SEQUENCE_NUMBER  \
# 25281              12.0                        1.0                57.0
# 25282              12.0                        1.0                57.0
# 25283              12.0                        1.0                57.0
# 25284              12.0                        1.0                57.0
# 25285              12.0                        1.0                57.0
#
#        M1_CURRENT_FEEDRATE  MACHINING_PROCESS  FEEDRATE  CLAMP_PRESSURE  \
# 25281                  3.0                End       3.0             2.5
# 25282                  3.0                End       3.0             2.5
# 25283                  3.0                End       3.0             2.5
# 25284                  3.0                End       3.0             2.5
# 25285                  3.0                End       3.0             2.5
#
#        TARGET
# 25281       1
# 25282       1
# 25283       1
# 25284       1
# 25285       1
#
# [5 rows x 51 columns]
# ##################### NA #####################
# X1_ACTUALPOSITION            0
# X1_ACTUALVELOCITY            0
# X1_ACTUALACCELERATION        0
# X1_COMMANDPOSITION           0
# X1_COMMANDVELOCITY           0
# X1_COMMANDACCELERATION       0
# X1_CURRENTFEEDBACK           0
# X1_DCBUSVOLTAGE              0
# X1_OUTPUTCURRENT             0
# X1_OUTPUTVOLTAGE             0
# X1_OUTPUTPOWER               0
# Y1_ACTUALPOSITION            0
# Y1_ACTUALVELOCITY            0
# Y1_ACTUALACCELERATION        0
# Y1_COMMANDPOSITION           0
# Y1_COMMANDVELOCITY           0
# Y1_COMMANDACCELERATION       0
# Y1_CURRENTFEEDBACK           0
# Y1_DCBUSVOLTAGE              0
# Y1_OUTPUTCURRENT             0
# Y1_OUTPUTVOLTAGE             0
# Y1_OUTPUTPOWER               0
# Z1_ACTUALPOSITION            0
# Z1_ACTUALVELOCITY            0
# Z1_ACTUALACCELERATION        0
# Z1_COMMANDPOSITION           0
# Z1_COMMANDVELOCITY           0
# Z1_COMMANDACCELERATION       0
# Z1_CURRENTFEEDBACK           0
# Z1_DCBUSVOLTAGE              0
# Z1_OUTPUTCURRENT             0
# Z1_OUTPUTVOLTAGE             0
# S1_ACTUALPOSITION            0
# S1_ACTUALVELOCITY            0
# S1_ACTUALACCELERATION        0
# S1_COMMANDPOSITION           0
# S1_COMMANDVELOCITY           0
# S1_COMMANDACCELERATION       0
# S1_CURRENTFEEDBACK           0
# S1_DCBUSVOLTAGE              0
# S1_OUTPUTCURRENT             0
# S1_OUTPUTVOLTAGE             0
# S1_OUTPUTPOWER               0
# S1_SYSTEMINERTIA             0
# M1_CURRENT_PROGRAM_NUMBER    0
# M1_SEQUENCE_NUMBER           0
# M1_CURRENT_FEEDRATE          0
# MACHINING_PROCESS            0
# FEEDRATE                     0
# CLAMP_PRESSURE               0
# TARGET                       0
# dtype: int64
# ##################### Quantiles #####################
#                                    0.00          0.05        0.50  \
# X1_ACTUALPOSITION          1.410000e+02  1.410000e+02  153.000000
# X1_ACTUALVELOCITY         -2.040000e+01 -6.130000e+00    0.000000
# X1_ACTUALACCELERATION     -1.280000e+03 -8.750000e+01    0.000000
# X1_COMMANDPOSITION         1.410000e+02  1.410000e+02  153.000000
# X1_COMMANDVELOCITY        -2.000000e+01 -6.000000e+00    0.000000
# X1_COMMANDACCELERATION    -1.000000e+03 -2.687500e+00    0.000000
# X1_CURRENTFEEDBACK        -2.340000e+01 -6.320000e+00   -0.666000
# X1_DCBUSVOLTAGE            2.780000e-19  2.790000e-19    0.066800
# X1_OUTPUTCURRENT           3.200000e+02  3.240000e+02  327.000000
# X1_OUTPUTVOLTAGE           0.000000e+00  0.000000e+00    7.140000
# X1_OUTPUTPOWER            -6.060000e-03 -2.137500e-05    0.000174
# Y1_ACTUALPOSITION          7.240000e+01  7.240000e+01   90.000000
# Y1_ACTUALVELOCITY         -3.280000e+01 -5.900000e+00    0.000000
# Y1_ACTUALACCELERATION     -1.260000e+03 -5.630000e+01    0.000000
# Y1_COMMANDPOSITION         7.240000e+01  7.240000e+01   90.000000
# Y1_COMMANDVELOCITY        -3.240000e+01 -6.000000e+00    0.000000
# Y1_COMMANDACCELERATION    -1.000000e+03 -2.780000e+00    0.000000
# Y1_CURRENTFEEDBACK        -2.780000e+01 -7.570000e+00    0.146000
# Y1_DCBUSVOLTAGE            2.680000e-19  2.780000e-19    0.057800
# Y1_OUTPUTCURRENT           3.190000e+02  3.230000e+02  326.000000
# Y1_OUTPUTVOLTAGE           0.000000e+00  0.000000e+00    4.930000
# Y1_OUTPUTPOWER            -4.920000e-03 -1.330000e-05    0.000004
# Z1_ACTUALPOSITION          2.750000e+01  2.750000e+01   29.500000
# Z1_ACTUALVELOCITY         -5.150000e+01 -1.250000e-01    0.000000
# Z1_ACTUALACCELERATION     -1.260000e+03 -1.250000e+01    0.000000
# Z1_COMMANDPOSITION         2.750000e+01  2.750000e+01   29.500000
# Z1_COMMANDVELOCITY        -5.000000e+01  0.000000e+00    0.000000
# Z1_COMMANDACCELERATION    -1.000000e+03  0.000000e+00    0.000000
# Z1_CURRENTFEEDBACK         0.000000e+00  0.000000e+00    0.000000
# Z1_DCBUSVOLTAGE            0.000000e+00  0.000000e+00    0.000000
# Z1_OUTPUTCURRENT           0.000000e+00  0.000000e+00    0.000000
# Z1_OUTPUTVOLTAGE           0.000000e+00  0.000000e+00    0.000000
# S1_ACTUALPOSITION         -2.150000e+03 -2.000000e+03 -112.500000
# S1_ACTUALVELOCITY         -6.900000e-02 -1.000000e-03   53.300000
# S1_ACTUALACCELERATION     -1.500000e+02 -5.740000e+01    0.000000
# S1_COMMANDPOSITION        -2.150000e+03 -2.000000e+03 -112.000000
# S1_COMMANDVELOCITY         0.000000e+00  0.000000e+00   53.300000
# S1_COMMANDACCELERATION    -9.540000e-07 -9.540000e-07    0.000000
# S1_CURRENTFEEDBACK        -8.280000e+00 -6.850000e-01   18.800000
# S1_DCBUSVOLTAGE            0.000000e+00  2.700000e-19    0.858000
# S1_OUTPUTCURRENT           2.900000e+02  3.170000e+02  322.000000
# S1_OUTPUTVOLTAGE           0.000000e+00  0.000000e+00  117.000000
# S1_OUTPUTPOWER            -2.960000e-03 -2.320000e-06    0.164000
# S1_SYSTEMINERTIA           1.200000e+01  1.200000e+01   12.000000
# M1_CURRENT_PROGRAM_NUMBER  0.000000e+00  1.000000e+00    1.000000
# M1_SEQUENCE_NUMBER         0.000000e+00  0.000000e+00   39.000000
# M1_CURRENT_FEEDRATE        3.000000e+00  3.000000e+00    6.000000
# FEEDRATE                   3.000000e+00  3.000000e+00    3.000000
# CLAMP_PRESSURE             2.500000e+00  2.500000e+00    3.000000
# TARGET                     0.000000e+00  0.000000e+00    1.000000
#
#                                    0.95          0.99       1.00
# X1_ACTUALPOSITION          1.980000e+02  1.980000e+02   198.0000
# X1_ACTUALVELOCITY          5.930000e+00  1.990000e+01    50.7000
# X1_ACTUALACCELERATION      8.750000e+01  1.449000e+02  1440.0000
# X1_COMMANDPOSITION         1.980000e+02  1.980000e+02   198.0000
# X1_COMMANDVELOCITY         6.000000e+00  2.000000e+01    50.0000
# X1_COMMANDACCELERATION     3.260000e+00  6.831500e+01  1000.0000
# X1_CURRENTFEEDBACK         6.000000e+00  8.206000e+00    27.1000
# X1_DCBUSVOLTAGE            1.170000e-01  1.560000e-01     0.3800
# X1_OUTPUTCURRENT           3.300000e+02  3.300000e+02   331.0000
# X1_OUTPUTVOLTAGE           2.480000e+01  3.310000e+01    75.4000
# X1_OUTPUTPOWER             3.227500e-03  5.690000e-03     0.0388
# Y1_ACTUALPOSITION          1.580000e+02  1.580000e+02   158.0000
# Y1_ACTUALVELOCITY          4.950000e+00  1.500000e+01    50.4000
# Y1_ACTUALACCELERATION      6.250000e+01  1.690000e+02  1460.0000
# Y1_COMMANDPOSITION         1.580000e+02  1.580000e+02   158.0000
# Y1_COMMANDVELOCITY         5.145000e+00  1.500000e+01    50.0000
# Y1_COMMANDACCELERATION     3.370000e+00  8.687500e+01  1000.0000
# Y1_CURRENTFEEDBACK         6.800000e+00  9.311500e+00    30.7000
# Y1_DCBUSVOLTAGE            1.470000e-01  1.930000e-01     0.4300
# Y1_OUTPUTCURRENT           3.290000e+02  3.320000e+02   333.0000
# Y1_OUTPUTVOLTAGE           2.050000e+01  4.920000e+01    76.8000
# Y1_OUTPUTPOWER             2.340000e-03  1.230000e-02     0.0424
# Z1_ACTUALPOSITION          1.190000e+02  1.190000e+02   119.0000
# Z1_ACTUALVELOCITY          2.500000e-02  4.990000e+01    50.9000
# Z1_ACTUALACCELERATION      1.250000e+01  5.000000e+01  1270.0000
# Z1_COMMANDPOSITION         1.190000e+02  1.190000e+02   119.0000
# Z1_COMMANDVELOCITY         0.000000e+00  5.000000e+01    50.0000
# Z1_COMMANDACCELERATION     0.000000e+00  0.000000e+00  1000.0000
# Z1_CURRENTFEEDBACK         0.000000e+00  0.000000e+00     0.0000
# Z1_DCBUSVOLTAGE            0.000000e+00  0.000000e+00     0.0000
# Z1_OUTPUTCURRENT           0.000000e+00  0.000000e+00     0.0000
# Z1_OUTPUTVOLTAGE           0.000000e+00  0.000000e+00     0.0000
# S1_ACTUALPOSITION          1.930000e+03  2.150000e+03  2150.0000
# S1_ACTUALVELOCITY          5.350000e+01  5.350000e+01    53.8000
# S1_ACTUALACCELERATION      5.580000e+01  7.660000e+01   150.0000
# S1_COMMANDPOSITION         1.930000e+03  2.150000e+03  2150.0000
# S1_COMMANDVELOCITY         5.330000e+01  5.330000e+01    53.3000
# S1_COMMANDACCELERATION     9.540000e-07  9.540000e-07   100.0000
# S1_CURRENTFEEDBACK         2.650000e+01  2.930000e+01    75.4000
# S1_DCBUSVOLTAGE            1.070000e+00  1.140000e+00     3.1600
# S1_OUTPUTCURRENT           3.300000e+02  3.310000e+02   332.0000
# S1_OUTPUTVOLTAGE           1.210000e+02  1.220000e+02   130.0000
# S1_OUTPUTPOWER             2.050000e-01  2.180000e-01     0.5690
# S1_SYSTEMINERTIA           1.200000e+01  1.200000e+01    12.0000
# M1_CURRENT_PROGRAM_NUMBER  1.000000e+00  4.000000e+00     4.0000
# M1_SEQUENCE_NUMBER         1.220000e+02  1.280000e+02   135.0000
# M1_CURRENT_FEEDRATE        5.000000e+01  5.000000e+01    50.0000
# FEEDRATE                   2.000000e+01  2.000000e+01    20.0000
# CLAMP_PRESSURE             4.000000e+00  4.000000e+00     4.0000
# TARGET                     1.000000e+00  1.000000e+00     1.0000

# %%
# Catch Numeric and Categorical Value


def grap_column_names(dataframe, categorical_th=10, cardinal_th=20):
    """
    It gives the names of categorical, numerical and categorical but cardinal variables in the data set.
    Note: Categorical variables with numerical appearance are also included."""

    """
    Cardinal Variables: Variables that are categorical and do not carry information,
    that is, have too many classes, are called variables with high cardinality.
    """

    """
    Returns
    ------
        categorical_cols: list
                Categorical variable list
        num_cols: list
                Numeric variable list
        categorical_but_cardinal: list
                Categorical variables with high cardinality list
    """
    # categorical_cols, categorical_but_cardinal
    categorical_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"]
    numeric_but_categorical = [col for col in dataframe.columns if dataframe[col].nunique() < categorical_th and
                   dataframe[col].dtypes != "O"]
    categorical_but_cardinal = [col for col in dataframe.columns if dataframe[col].nunique() > cardinal_th and
                   dataframe[col].dtypes == "O"]
    categorical_cols = categorical_cols + numeric_but_categorical
    categorical_cols = [col for col in categorical_cols if col not in categorical_but_cardinal]

    # num_cols
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in numeric_but_categorical]

    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f'categorical_cols: {len(categorical_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'categorical_but_cardinal: {len(categorical_but_cardinal)}')
    print(f'numeric_but_categorical: {len(numeric_but_categorical)}')

    return categorical_cols, num_cols, categorical_but_cardinal

cat_cols, num_cols, cat_but_car = grap_column_names(df)

print("\n\nCategorical Columns: \n", cat_cols)
print("\n\nNumeric Columns: \n", num_cols)
[print("\n\nCategorical but Cardinal EMPTY!!!\n") if cat_but_car == [] else print("Categorical but Cardinal: \n", cat_but_car)]
print("#"*50)
# Out:
# Observations: 25286
# Variables: 51
# categorical_cols: 12
# num_cols: 39
# categorical_but_cardinal: 0
# numeric_but_categorical: 11
#
#
# Categorical Columns:
#  ['MACHINING_PROCESS', 'Z1_CURRENTFEEDBACK', 'Z1_DCBUSVOLTAGE', 'Z1_OUTPUTCURRENT', 'Z1_OUTPUTVOLTAGE', 'S1_COMMANDACCELERATION', 'S1_SYSTEMINERTIA', 'M1_CURRENT_PROGRAM_NUMBER', 'M1_CURRENT_FEEDRATE', 'FEEDRATE', 'CLAMP_PRESSURE', 'TARGET']
#
#
# Numeric Columns:
#  ['X1_ACTUALPOSITION', 'X1_ACTUALVELOCITY', 'X1_ACTUALACCELERATION', 'X1_COMMANDPOSITION', 'X1_COMMANDVELOCITY', 'X1_COMMANDACCELERATION', 'X1_CURRENTFEEDBACK', 'X1_DCBUSVOLTAGE', 'X1_OUTPUTCURRENT', 'X1_OUTPUTVOLTAGE', 'X1_OUTPUTPOWER', 'Y1_ACTUALPOSITION', 'Y1_ACTUALVELOCITY', 'Y1_ACTUALACCELERATION', 'Y1_COMMANDPOSITION', 'Y1_COMMANDVELOCITY', 'Y1_COMMANDACCELERATION', 'Y1_CURRENTFEEDBACK', 'Y1_DCBUSVOLTAGE', 'Y1_OUTPUTCURRENT', 'Y1_OUTPUTVOLTAGE', 'Y1_OUTPUTPOWER', 'Z1_ACTUALPOSITION', 'Z1_ACTUALVELOCITY', 'Z1_ACTUALACCELERATION', 'Z1_COMMANDPOSITION', 'Z1_COMMANDVELOCITY', 'Z1_COMMANDACCELERATION', 'S1_ACTUALPOSITION', 'S1_ACTUALVELOCITY', 'S1_ACTUALACCELERATION', 'S1_COMMANDPOSITION', 'S1_COMMANDVELOCITY', 'S1_CURRENTFEEDBACK', 'S1_DCBUSVOLTAGE', 'S1_OUTPUTCURRENT', 'S1_OUTPUTVOLTAGE', 'S1_OUTPUTPOWER', 'M1_SEQUENCE_NUMBER']
#
#
# Categorical but Cardinal EMPTY!!!
#
# ##################################################

# %%
# Categorical Variables Analysis

def cat_summary(dataframe, col_name, plot=False):
    """
    This function shows the frequency of categorical variables.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    col_name : str
        The name of the column to be analyzed.
    plot : bool, optional
        The default is False.
    Returns
    -------
    None.
    """
    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                        "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)}))
    print("##########################################")
    if plot:
        sns.countplot(x=dataframe[col_name], data=dataframe)
        plt.show()

for col in cat_cols:
    cat_summary(df,col)
print("#"*50)
# Drop cols should be Numeric
cat_cols = [col for col in cat_cols if col not in cat_to_numeric]

print(cat_cols)
# Out:
#                    MACHINING_PROCESS      Ratio
# MACHINING_PROCESS
# Layer 1 Up                      4085  16.155185
# Repositioning                   3377  13.355216
# Layer 2 Up                      3104  12.275568
# Layer 3 Up                      2794  11.049593
# Layer 1 Down                    2655  10.499881
# End                             2585  10.223048
# Layer 2 Down                    2528   9.997627
# Layer 3 Down                    2354   9.309499
# Prep                            1795   7.098790
# end                                8   0.031638
# Starting                           1   0.003955
# ##########################################
#                     Z1_CURRENTFEEDBACK  Ratio
# Z1_CURRENTFEEDBACK
# 0.0                              25286  100.0
# ##########################################
#                  Z1_DCBUSVOLTAGE  Ratio
# Z1_DCBUSVOLTAGE
# 0.0                        25286  100.0
# ##########################################
#                   Z1_OUTPUTCURRENT  Ratio
# Z1_OUTPUTCURRENT
# 0.0                          25286  100.0
# ##########################################
#                   Z1_OUTPUTVOLTAGE  Ratio
# Z1_OUTPUTVOLTAGE
# 0.0                          25286  100.0
# ##########################################
#                         S1_COMMANDACCELERATION      Ratio
# S1_COMMANDACCELERATION
#  0.000000e+00                            18335  72.510480
#  9.540000e-07                             3478  13.754647
# -9.540000e-07                             3375  13.347307
#  1.000000e+02                               97   0.383611
#  5.000000e+01                                1   0.003955
# ##########################################
#                   S1_SYSTEMINERTIA  Ratio
# S1_SYSTEMINERTIA
# 12.0                         25286  100.0
# ##########################################
#                            M1_CURRENT_PROGRAM_NUMBER      Ratio
# M1_CURRENT_PROGRAM_NUMBER
# 1.0                                            24317  96.167840
# 0.0                                              705   2.788104
# 4.0                                              264   1.044056
# ##########################################
#                      M1_CURRENT_FEEDRATE      Ratio
# M1_CURRENT_FEEDRATE
# 3.0                                11788  46.618682
# 50.0                                6253  24.729099
# 6.0                                 4889  19.334810
# 20.0                                1426   5.639484
# 12.0                                 512   2.024836
# 15.0                                 418   1.653089
# ##########################################
#           FEEDRATE      Ratio
# FEEDRATE
# 3.0          13558  53.618603
# 6.0           5785  22.878273
# 20.0          3902  15.431464
# 12.0          1301   5.145140
# 15.0           740   2.926521
# ##########################################
#                 CLAMP_PRESSURE      Ratio
# CLAMP_PRESSURE
# 4.0                      11777  46.575180
# 3.0                       8574  33.908091
# 2.5                       4935  19.516729
# ##########################################
#         TARGET      Ratio
# TARGET
# 1        13308  52.629914
# 0        11978  47.370086
# ##########################################
# ##################################################
# ['MACHINING_PROCESS', 'M1_CURRENT_PROGRAM_NUMBER', 'TARGET']

# %%
# Numeric Variables Analysis

for col in cat_to_numeric:
    num_cols.append(col)

def numerical_col_summary(dataframe, col_name, plot=False):

    """
    This function shows the frequency of numerical variables.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    col_name : str
        The name of the column to be analyzed.
    plot : bool, optional
        The default is False.
    Returns
    -------
    None.
    """
    print(dataframe[col_name].describe([0.01, 0.05, 0.75, 0.90, 0.99]).T)
    print("##########################################")
    if plot:
        sns.histplot(dataframe[col_name], kde=True)
        plt.xlabel(col_name)
        plt.title(f"{col_name} Distribution")
        plt.show()

for col in num_cols:
    numerical_col_summary(df,col)
print("#"*50)
# Out:
# count    25286.000000
# mean       159.052045
# std         19.330873
# min        141.000000
# 1%         141.000000
# 5%         141.000000
# 50%        153.000000
# 75%        162.000000
# 90%        198.000000
# 99%        198.000000
# max        198.000000
# Name: X1_ACTUALPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.288657
# std          5.658260
# min        -20.400000
# 1%         -18.100000
# 5%          -6.130000
# 50%          0.000000
# 75%          0.200000
# 90%          3.100000
# 99%         19.900000
# max         50.700000
# Name: X1_ACTUALVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.094264
# std         93.877623
# min      -1280.000000
# 1%        -138.000000
# 5%         -87.500000
# 50%          0.000000
# 75%         25.000000
# 90%         62.500000
# 99%        144.900000
# max       1440.000000
# Name: X1_ACTUALACCELERATION, dtype: float64
# ##########################################
# count    25286.000000
# mean       159.050700
# std         19.331144
# min        141.000000
# 1%         141.000000
# 5%         141.000000
# 50%        153.000000
# 75%        162.000000
# 90%        198.000000
# 99%        198.000000
# max        198.000000
# Name: X1_COMMANDPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.283076
# std          5.664309
# min        -20.000000
# 1%         -17.900000
# 5%          -6.000000
# 50%          0.000000
# 75%          0.000000
# 90%          3.000000
# 99%         20.000000
# max         50.000000
# Name: X1_COMMANDVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.253215
# std         72.594951
# min      -1000.000000
# 1%         -53.545000
# 5%          -2.687500
# 50%          0.000000
# 75%          0.000000
# 90%          1.470000
# 99%         68.315000
# max       1000.000000
# Name: X1_COMMANDACCELERATION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.469714
# std          4.220750
# min        -23.400000
# 1%          -8.070000
# 5%          -6.320000
# 50%         -0.666000
# 75%          3.140000
# 90%          5.240000
# 99%          8.206000
# max         27.100000
# Name: X1_CURRENTFEEDBACK, dtype: float64
# ##########################################
# count    2.528600e+04
# mean     6.603073e-02
# std      3.700384e-02
# min      2.780000e-19
# 1%       2.780000e-19
# 5%       2.790000e-19
# 50%      6.680000e-02
# 75%      9.130000e-02
# 90%      1.070000e-01
# 99%      1.560000e-01
# max      3.800000e-01
# Name: X1_DCBUSVOLTAGE, dtype: float64
# ##########################################
# count    25286.000000
# mean       326.945859
# std          1.459937
# min        320.000000
# 1%         323.000000
# 5%         324.000000
# 50%        327.000000
# 75%        327.000000
# 90%        329.000000
# 99%        330.000000
# max        331.000000
# Name: X1_OUTPUTCURRENT, dtype: float64
# ##########################################
# count    25286.000000
# mean         7.986942
# std          7.710379
# min          0.000000
# 1%           0.000000
# 5%           0.000000
# 50%          7.140000
# 75%         10.200000
# 90%         14.100000
# 99%         33.100000
# max         75.400000
# Name: X1_OUTPUTVOLTAGE, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.000610
# std          0.001565
# min         -0.006060
# 1%          -0.000035
# 5%          -0.000021
# 50%          0.000174
# 75%          0.000585
# 90%          0.001230
# 99%          0.005690
# max          0.038800
# Name: X1_OUTPUTPOWER, dtype: float64
# ##########################################
# count    25286.000000
# mean        99.230064
# std         29.244880
# min         72.400000
# 1%          72.400000
# 5%          72.400000
# 50%         90.000000
# 75%        105.000000
# 90%        158.000000
# 99%        158.000000
# max        158.000000
# Name: Y1_ACTUALPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.422932
# std          6.006439
# min        -32.800000
# 1%         -32.300000
# 5%          -5.900000
# 50%          0.000000
# 75%          0.100000
# 90%          2.950000
# 99%         15.000000
# max         50.400000
# Name: Y1_ACTUALVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.928832
# std         85.074580
# min      -1260.000000
# 1%        -150.000000
# 5%         -56.300000
# 50%          0.000000
# 75%         18.800000
# 90%         43.800000
# 99%        169.000000
# max       1460.000000
# Name: Y1_ACTUALACCELERATION, dtype: float64
# ##########################################
# count    25286.000000
# mean        99.226271
# std         29.242802
# min         72.400000
# 1%          72.400000
# 5%          72.400000
# 50%         90.000000
# 75%        105.000000
# 90%        158.000000
# 99%        158.000000
# max        158.000000
# Name: Y1_COMMANDPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.412075
# std          6.004721
# min        -32.400000
# 1%         -32.400000
# 5%          -6.000000
# 50%          0.000000
# 75%          0.000000
# 90%          3.000000
# 99%         15.000000
# max         50.000000
# Name: Y1_COMMANDVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean         1.484158
# std         81.358073
# min      -1000.000000
# 1%         -58.190000
# 5%          -2.780000
# 50%          0.000000
# 75%          0.000000
# 90%          1.590000
# 99%         86.875000
# max       1000.000000
# Name: Y1_COMMANDACCELERATION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.061681
# std          4.469548
# min        -27.800000
# 1%         -10.400000
# 5%          -7.570000
# 50%          0.146000
# 75%          2.900000
# 90%          5.620000
# 99%          9.311500
# max         30.700000
# Name: Y1_CURRENTFEEDBACK, dtype: float64
# ##########################################
# count    2.528600e+04
# mean     6.398315e-02
# std      4.777806e-02
# min      2.680000e-19
# 1%       2.680000e-19
# 5%       2.780000e-19
# 50%      5.780000e-02
# 75%      9.557500e-02
# 90%      1.270000e-01
# 99%      1.930000e-01
# max      4.300000e-01
# Name: Y1_DCBUSVOLTAGE, dtype: float64
# ##########################################
# count    25286.000000
# mean       325.862058
# std          1.804164
# min        319.000000
# 1%         322.000000
# 5%         323.000000
# 50%        326.000000
# 75%        326.000000
# 90%        328.000000
# 99%        332.000000
# max        333.000000
# Name: Y1_OUTPUTCURRENT, dtype: float64
# ##########################################
# count    25286.000000
# mean         7.068352
# std          8.601484
# min          0.000000
# 1%           0.000000
# 5%           0.000000
# 50%          4.930000
# 75%          9.610000
# 90%         13.400000
# 99%         49.200000
# max         76.800000
# Name: Y1_OUTPUTVOLTAGE, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.000637
# std          0.002098
# min         -0.004920
# 1%          -0.000040
# 5%          -0.000013
# 50%          0.000004
# 75%          0.000506
# 90%          0.001110
# 99%          0.012300
# max          0.042400
# Name: Y1_OUTPUTPOWER, dtype: float64
# ##########################################
# count    25286.000000
# mean        47.780638
# std         34.255650
# min         27.500000
# 1%          27.500000
# 5%          27.500000
# 50%         29.500000
# 75%         55.500000
# 90%        119.000000
# 99%        119.000000
# max        119.000000
# Name: Z1_ACTUALPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.328759
# std          7.635223
# min        -51.500000
# 1%         -33.700000
# 5%          -0.125000
# 50%          0.000000
# 75%          0.000000
# 90%          0.025000
# 99%         49.900000
# max         50.900000
# Name: Z1_ACTUALVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.103658
# std         66.442671
# min      -1260.000000
# 1%         -43.800000
# 5%         -12.500000
# 50%          0.000000
# 75%          6.250000
# 90%         12.500000
# 99%         50.000000
# max       1270.000000
# Name: Z1_ACTUALACCELERATION, dtype: float64
# ##########################################
# count    25286.000000
# mean        47.778031
# std         34.252517
# min         27.500000
# 1%          27.500000
# 5%          27.500000
# 50%         29.500000
# 75%         55.500000
# 90%        119.000000
# 99%        119.000000
# max        119.000000
# Name: Z1_COMMANDPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.328464
# std          7.637045
# min        -50.000000
# 1%         -33.700000
# 5%           0.000000
# 50%          0.000000
# 75%          0.000000
# 90%          0.000000
# 99%         50.000000
# max         50.000000
# Name: Z1_COMMANDVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.134118
# std         61.988683
# min      -1000.000000
# 1%           0.000000
# 5%           0.000000
# 50%          0.000000
# 75%          0.000000
# 90%          0.000000
# 99%          0.000000
# max       1000.000000
# Name: Z1_COMMANDACCELERATION, dtype: float64
# ##########################################
# count    25286.000000
# mean      -115.373082
# std       1212.730873
# min      -2150.000000
# 1%       -2100.000000
# 5%       -2000.000000
# 50%       -112.500000
# 75%        860.750000
# 90%       1620.000000
# 99%       2150.000000
# max       2150.000000
# Name: S1_ACTUALPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        38.986424
# std         23.491267
# min         -0.069000
# 1%          -0.002000
# 5%          -0.001000
# 50%         53.300000
# 75%         53.400000
# 90%         53.400000
# 99%         53.500000
# max         53.800000
# Name: S1_ACTUALVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.248602
# std         32.204079
# min       -150.000000
# 1%         -80.100000
# 5%         -57.400000
# 50%          0.000000
# 75%         17.500000
# 90%         43.800000
# 99%         76.600000
# max        150.000000
# Name: S1_ACTUALACCELERATION, dtype: float64
# ##########################################
# count    25286.000000
# mean      -115.051536
# std       1212.766136
# min      -2150.000000
# 1%       -2100.000000
# 5%       -2000.000000
# 50%       -112.000000
# 75%        861.750000
# 90%       1620.000000
# 99%       2150.000000
# max       2150.000000
# Name: S1_COMMANDPOSITION, dtype: float64
# ##########################################
# count    25286.000000
# mean        38.650012
# std         23.758090
# min          0.000000
# 1%           0.000000
# 5%           0.000000
# 50%         53.300000
# 75%         53.300000
# 90%         53.300000
# 99%         53.300000
# max         53.300000
# Name: S1_COMMANDVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean        15.243948
# std         10.222419
# min         -8.280000
# 1%          -1.800000
# 5%          -0.685000
# 50%         18.800000
# 75%         22.300000
# 90%         25.100000
# 99%         29.300000
# max         75.400000
# Name: S1_CURRENTFEEDBACK, dtype: float64
# ##########################################
# count    2.528600e+04
# mean     6.692938e-01
# std      4.332413e-01
# min      0.000000e+00
# 1%       0.000000e+00
# 5%       2.700000e-19
# 50%      8.580000e-01
# 75%      9.520000e-01
# 90%      1.030000e+00
# 99%      1.140000e+00
# max      3.160000e+00
# Name: S1_DCBUSVOLTAGE, dtype: float64
# ##########################################
# count    25286.000000
# mean       322.784505
# std          4.293571
# min        290.000000
# 1%         315.000000
# 5%         317.000000
# 50%        322.000000
# 75%        327.000000
# 90%        329.000000
# 99%        331.000000
# max        332.000000
# Name: S1_OUTPUTCURRENT, dtype: float64
# ##########################################
# count    25286.000000
# mean        85.479195
# std         52.531863
# min          0.000000
# 1%           0.000000
# 5%           0.000000
# 50%        117.000000
# 75%        119.000000
# 90%        120.000000
# 99%        122.000000
# max        130.000000
# Name: S1_OUTPUTVOLTAGE, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.127405
# std          0.080753
# min         -0.002960
# 1%          -0.000011
# 5%          -0.000002
# 50%          0.164000
# 75%          0.183000
# 90%          0.197000
# 99%          0.218000
# max          0.569000
# Name: S1_OUTPUTPOWER, dtype: float64
# ##########################################
# count    25286.000000
# mean        47.345013
# std         43.826214
# min          0.000000
# 1%           0.000000
# 5%           0.000000
# 50%         39.000000
# 75%         85.000000
# 90%        112.500000
# 99%        128.000000
# max        135.000000
# Name: M1_SEQUENCE_NUMBER, dtype: float64
# ##########################################
# count    25286.000000
# mean         7.123942
# std          6.167036
# min          3.000000
# 1%           3.000000
# 5%           3.000000
# 50%          3.000000
# 75%          6.000000
# 90%         20.000000
# 99%         20.000000
# max         20.000000
# Name: FEEDRATE, dtype: float64
# ##########################################
# count    25286.000000
# mean         3.368168
# std          0.615639
# min          2.500000
# 1%           2.500000
# 5%           2.500000
# 50%          3.000000
# 75%          4.000000
# 90%          4.000000
# 99%          4.000000
# max          4.000000
# Name: CLAMP_PRESSURE, dtype: float64
# ##########################################
# count    25286.000000
# mean        -0.328464
# std          7.637045
# min        -50.000000
# 1%         -33.700000
# 5%           0.000000
# 50%          0.000000
# 75%          0.000000
# 90%          0.000000
# 99%         50.000000
# max         50.000000
# Name: Z1_COMMANDVELOCITY, dtype: float64
# ##########################################
# count    25286.000000
# mean         0.134118
# std         61.988683
# min      -1000.000000
# 1%           0.000000
# 5%           0.000000
# 50%          0.000000
# 75%          0.000000
# 90%          0.000000
# 99%          0.000000
# max       1000.000000
# Name: Z1_COMMANDACCELERATION, dtype: float64
# ##########################################
# count    25286.0
# mean         0.0
# std          0.0
# min          0.0
# 1%           0.0
# 5%           0.0
# 50%          0.0
# 75%          0.0
# 90%          0.0
# 99%          0.0
# max          0.0
# Name: Z1_CURRENTFEEDBACK, dtype: float64
# ##########################################
# count    25286.0
# mean         0.0
# std          0.0
# min          0.0
# 1%           0.0
# 5%           0.0
# 50%          0.0
# 75%          0.0
# 90%          0.0
# 99%          0.0
# max          0.0
# Name: Z1_DCBUSVOLTAGE, dtype: float64
# ##########################################
# count    25286.0
# mean         0.0
# std          0.0
# min          0.0
# 1%           0.0
# 5%           0.0
# 50%          0.0
# 75%          0.0
# 90%          0.0
# 99%          0.0
# max          0.0
# Name: Z1_OUTPUTCURRENT, dtype: float64
# ##########################################
# count    25286.0
# mean         0.0
# std          0.0
# min          0.0
# 1%           0.0
# 5%           0.0
# 50%          0.0
# 75%          0.0
# 90%          0.0
# 99%          0.0
# max          0.0
# Name: Z1_OUTPUTVOLTAGE, dtype: float64
# ##########################################
# count    2.528600e+04
# mean     3.855889e-01
# std      6.189738e+00
# min     -9.540000e-07
# 1%      -9.540000e-07
# 5%      -9.540000e-07
# 50%      0.000000e+00
# 75%      0.000000e+00
# 90%      9.540000e-07
# 99%      9.540000e-07
# max      1.000000e+02
# Name: S1_COMMANDACCELERATION, dtype: float64
# ##########################################
# count    25286.0
# mean        12.0
# std          0.0
# min         12.0
# 1%          12.0
# 5%          12.0
# 50%         12.0
# 75%         12.0
# 90%         12.0
# 99%         12.0
# max         12.0
# Name: S1_SYSTEMINERTIA, dtype: float64
# ##########################################
# count    25286.000000
# mean        16.542039
# std         19.620219
# min          3.000000
# 1%           3.000000
# 5%           3.000000
# 50%          6.000000
# 75%         20.000000
# 90%         50.000000
# 99%         50.000000
# max         50.000000
# Name: M1_CURRENT_FEEDRATE, dtype: float64
# ##########################################
# ##################################################

# %%
# Target Variable Analysis (Dependent Variable) - Categorical

"Non-Sense to analyze the target variable, There is only 1 categorical variable"

def target_summary_with_cat(dataframe, target, categorical_col):
    """
    This function shows the mean of the target variable according to the categorical variable.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    target : str
        The name of the target variable.
    categorical_col : str
        The name of the categorical variable.
    Returns
    -------
    None.
    """
    print(categorical_col)
    print(pd.DataFrame({"TARGET_MEAN": dataframe.groupby(categorical_col)[target].mean(),
                        "Count": dataframe[categorical_col].value_counts(),
                        "Ratio": 100 * dataframe[categorical_col].value_counts() / len(dataframe)}), end="\n\n\n")

for col in cat_cols:
    target_summary_with_cat(df, "TARGET", col)

print("#"*50)
# Out:
# MACHINING_PROCESS
#                    TARGET_MEAN  Count      Ratio
# MACHINING_PROCESS
# End                   0.487427   2585  10.223048
# Layer 1 Down          0.567232   2655  10.499881
# Layer 1 Up            0.493758   4085  16.155185
# Layer 2 Down          0.509494   2528   9.997627
# Layer 2 Up            0.533505   3104  12.275568
# Layer 3 Down          0.587511   2354   9.309499
# Layer 3 Up            0.582677   2794  11.049593
# Prep                  0.582730   1795   7.098790
# Repositioning         0.451288   3377  13.355216
# Starting              0.000000      1   0.003955
# end                   0.000000      8   0.031638
#
#
# M1_CURRENT_PROGRAM_NUMBER
#                            TARGET_MEAN  Count      Ratio
# M1_CURRENT_PROGRAM_NUMBER
# 0.0                           0.000000    705   2.788104
# 1.0                           0.547271  24317  96.167840
# 4.0                           0.000000    264   1.044056
#
#
# TARGET
#         TARGET_MEAN  Count      Ratio
# TARGET
# 0               0.0  11978  47.370086
# 1               1.0  13308  52.629914
#
#
# ##################################################

# %%
#Target Variable Analysis (Dependent Variable) - Numeric

def target_summary_with_num(dataframe, target, numerical_col):
    """
    This function shows the average of numerical variables according to the target variable.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    target : str
        The name of the target variable.
    numerical_col : str
        The name of the numerical variable.
    Returns
    -------
    None.
    """
    print(dataframe.groupby(target).agg({numerical_col: ["mean", "median", "count"]}), end="\n\n\n")

for col in num_cols:
    target_summary_with_num(df, "TARGET", col)
print("#"*50)
# Out:
#        X1_ACTUALPOSITION
#                     mean median  count
# TARGET
# 0             160.924946  154.0  11978
# 1             157.366321  151.0  13308
#
#
#        X1_ACTUALVELOCITY
#                     mean median  count
# TARGET
# 0              -0.238839    0.0  11978
# 1              -0.333496    0.0  13308
#
#
#        X1_ACTUALACCELERATION
#                         mean median  count
# TARGET
# 0                  -0.316067    0.0  11978
# 1                   0.463586    0.0  13308
#
#
#        X1_COMMANDPOSITION
#                      mean median  count
# TARGET
# 0              160.925864  154.0  11978
# 1              157.362940  151.0  13308
#
#
#        X1_COMMANDVELOCITY
#                      mean median  count
# TARGET
# 0               -0.229884    0.0  11978
# 1               -0.330953    0.0  13308
#
#
#        X1_COMMANDACCELERATION
#                          mean median  count
# TARGET
# 0                    0.680640    0.0  11978
# 1                   -0.131494    0.0  13308
#
#
#        X1_CURRENTFEEDBACK
#                      mean median  count
# TARGET
# 0               -0.376596 -0.392  11978
# 1               -0.553526 -1.100  13308
#
#
#        X1_DCBUSVOLTAGE
#                   mean  median  count
# TARGET
# 0             0.063033  0.0665  11978
# 1             0.068729  0.0670  13308
#
#
#        X1_OUTPUTCURRENT
#                    mean median  count
# TARGET
# 0            327.070463  327.0  11978
# 1            326.833709  327.0  13308
#
#
#        X1_OUTPUTVOLTAGE
#                    mean median  count
# TARGET
# 0              7.376061   6.93  11978
# 1              8.536772   7.33  13308
#
#
#        X1_OUTPUTPOWER
#                  mean    median  count
# TARGET
# 0            0.000514  0.000149  11978
# 1            0.000697  0.000200  13308
#
#
#        Y1_ACTUALPOSITION
#                     mean median  count
# TARGET
# 0             102.030890   91.6  11978
# 1              96.709152   89.5  13308
#
#
#        Y1_ACTUALVELOCITY
#                     mean median  count
# TARGET
# 0              -0.341857    0.0  11978
# 1              -0.495904    0.0  13308
#
#
#        Y1_ACTUALACCELERATION
#                         mean median  count
# TARGET
# 0                   0.851824    0.0  11978
# 1                   0.998144    0.0  13308
#
#
#        Y1_COMMANDPOSITION
#                      mean median  count
# TARGET
# 0              102.028694   91.6  11978
# 1               96.703922   89.5  13308
#
#
#        Y1_COMMANDVELOCITY
#                      mean median  count
# TARGET
# 0               -0.333459    0.0  11978
# 1               -0.482834    0.0  13308
#
#
#        Y1_COMMANDACCELERATION
#                          mean median  count
# TARGET
# 0                    1.082130    0.0  11978
# 1                    1.846008    0.0  13308
#
#
#        Y1_CURRENTFEEDBACK
#                      mean  median  count
# TARGET
# 0               -0.038142  0.1325  11978
# 1               -0.082867  0.1630  13308
#
#
#        Y1_DCBUSVOLTAGE
#                   mean  median  count
# TARGET
# 0             0.061415  0.0556  11978
# 1             0.066295  0.0595  13308
#
#
#        Y1_OUTPUTCURRENT
#                    mean median  count
# TARGET
# 0            326.198280  326.0  11978
# 1            325.559438  326.0  13308
#
#
#        Y1_OUTPUTVOLTAGE
#                    mean median  count
# TARGET
# 0              6.558125   4.78  11978
# 1              7.527587   5.09  13308
#
#
#        Y1_OUTPUTPOWER
#                  mean    median  count
# TARGET
# 0            0.000536  0.000004  11978
# 1            0.000727  0.000005  13308
#
#
#        Z1_ACTUALPOSITION
#                     mean median  count
# TARGET
# 0              50.114118   29.5  11978
# 1              45.680365   29.7  13308
#
#
#        Z1_ACTUALVELOCITY
#                     mean median  count
# TARGET
# 0              -0.262986    0.0  11978
# 1              -0.387959    0.0  13308
#
#
#        Z1_ACTUALACCELERATION
#                         mean median  count
# TARGET
# 0                   0.033107    0.0  11978
# 1                  -0.226755    0.0  13308
#
#
#        Z1_COMMANDPOSITION
#                      mean median  count
# TARGET
# 0               50.111688   29.5  11978
# 1               45.677600   29.7  13308
#
#
#        Z1_COMMANDVELOCITY
#                      mean median  count
# TARGET
# 0               -0.263547    0.0  11978
# 1               -0.386894    0.0  13308
#
#
#        Z1_COMMANDACCELERATION
#                          mean median  count
# TARGET
# 0                    0.090633    0.0  11978
# 1                    0.173257    0.0  13308
#
#
#        S1_ACTUALPOSITION
#                     mean  median  count
# TARGET
# 0            -124.334830  -43.45  11978
# 1            -107.306971 -181.50  13308
#
#
#        S1_ACTUALVELOCITY
#                     mean median  count
# TARGET
# 0              38.447204   53.3  11978
# 1              39.471754   53.3  13308
#
#
#        S1_ACTUALACCELERATION
#                         mean median  count
# TARGET
# 0                   0.626674    0.0  11978
# 1                  -0.091686    0.0  13308
#
#
#        S1_COMMANDPOSITION
#                      mean  median  count
# TARGET
# 0             -124.021823  -42.95  11978
# 1             -106.977738 -181.00  13308
#
#
#        S1_COMMANDVELOCITY
#                      mean median  count
# TARGET
# 0               38.149332   53.3  11978
# 1               39.100654   53.3  13308
#
#
#        S1_CURRENTFEEDBACK
#                      mean median  count
# TARGET
# 0               15.004511   18.7  11978
# 1               15.459456   18.8  13308
#
#
#        S1_DCBUSVOLTAGE
#                   mean median  count
# TARGET
# 0             0.660987  0.857  11978
# 1             0.676770  0.859  13308
#
#
#        S1_OUTPUTCURRENT
#                    mean median  count
# TARGET
# 0            323.032226  323.0  11978
# 1            322.561542  322.0  13308
#
#
#        S1_OUTPUTVOLTAGE
#                    mean median  count
# TARGET
# 0             84.419369  117.0  11978
# 1             86.433102  117.0  13308
#
#
#        S1_OUTPUTPOWER
#                  mean median  count
# TARGET
# 0            0.125930  0.164  11978
# 1            0.128733  0.164  13308
#
#
#        M1_SEQUENCE_NUMBER
#                      mean median  count
# TARGET
# 0               46.608699   38.0  11978
# 1               48.007740   40.0  13308
#
#
#         FEEDRATE
#             mean median  count
# TARGET
# 0       6.801469    3.0  11978
# 1       7.414187    3.0  13308
#
#
#        CLAMP_PRESSURE
#                  mean median  count
# TARGET
# 0            3.308566    3.0  11978
# 1            3.421814    4.0  13308
#
#
#        Z1_COMMANDVELOCITY
#                      mean median  count
# TARGET
# 0               -0.263547    0.0  11978
# 1               -0.386894    0.0  13308
#
#
#        Z1_COMMANDACCELERATION
#                          mean median  count
# TARGET
# 0                    0.090633    0.0  11978
# 1                    0.173257    0.0  13308
#
#
#        Z1_CURRENTFEEDBACK
#                      mean median  count
# TARGET
# 0                     0.0    0.0  11978
# 1                     0.0    0.0  13308
#
#
#        Z1_DCBUSVOLTAGE
#                   mean median  count
# TARGET
# 0                  0.0    0.0  11978
# 1                  0.0    0.0  13308
#
#
#        Z1_OUTPUTCURRENT
#                    mean median  count
# TARGET
# 0                   0.0    0.0  11978
# 1                   0.0    0.0  13308
#
#
#        Z1_OUTPUTVOLTAGE
#                    mean median  count
# TARGET
# 0                   0.0    0.0  11978
# 1                   0.0    0.0  13308
#
#
#        S1_COMMANDACCELERATION
#                          mean median  count
# TARGET
# 0                    0.367340    0.0  11978
# 1                    0.402014    0.0  13308
#
#
#        S1_SYSTEMINERTIA
#                    mean median  count
# TARGET
# 0                  12.0   12.0  11978
# 1                  12.0   12.0  13308
#
#
#        M1_CURRENT_FEEDRATE
#                       mean median  count
# TARGET
# 0                15.278344    6.0  11978
# 1                17.679441    6.0  13308
#
#
# ##################################################

# %%
# 7. Outlier Detection
# Outlier List below
"""
X1_ACTUALPOSITION: False, X1_ACTUALVELOCITY: True, X1_ACTUALACCELERATION: True
X1_COMMANDPOSITION: False, X1_COMMANDVELOCITY: True, X1_COMMANDACCELERATION: True
X1_CURRENTFEEDBACK: True, X1_DCBUSVOLTAGE: True, X1_OUTPUTCURRENT: False
X1_OUTPUTVOLTAGE: True, X1_OUTPUTPOWER: True, Y1_ACTUALPOSITION: False
Y1_ACTUALVELOCITY: True, Y1_ACTUALACCELERATION: True, Y1_COMMANDPOSITION: False
Y1_COMMANDVELOCITY: True, Y1_COMMANDACCELERATION: True, Y1_CURRENTFEEDBACK: True
Y1_DCBUSVOLTAGE: True, Y1_OUTPUTCURRENT: False, Y1_OUTPUTVOLTAGE: True
Y1_OUTPUTPOWER: True, Z1_ACTUALPOSITION: False, Z1_ACTUALVELOCITY: True
Z1_ACTUALACCELERATION: True, Z1_COMMANDPOSITION: False, Z1_COMMANDVELOCITY: True
Z1_COMMANDACCELERATION: True, S1_ACTUALPOSITION: False, S1_ACTUALVELOCITY: False
S1_ACTUALACCELERATION: False, S1_COMMANDPOSITION: False, S1_COMMANDVELOCITY: False
S1_CURRENTFEEDBACK: True, S1_DCBUSVOLTAGE: True, S1_OUTPUTCURRENT: True
S1_OUTPUTVOLTAGE: False, S1_OUTPUTPOWER: True, FEEDRATE: False
CLAMP_PRESSURE: False
"""

def outlier_thresholds(dataframe, col_name, q1=0.05, q3=0.95):
    """
    This function calculates the lower and upper limits for the outliers.

    Calculation:
    Interquantile range = q3 - q1
    Up limit = q3 + 1.5 * interquantile range
    Low limit = q1 - 1.5 * interquantile range

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    col_name : str
        The name of the column to be analyzed.
    q1 : float, optional
        The default is 0.05.
    q3 : float, optional
        The default is 0.95.
    Returns
    -------
    low_limit, up_limit : float
        The lower and upper limits for the outliers.
    """

    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)

    interquantile_range = quartile3 - quartile1

    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range

    return low_limit, up_limit

def check_outlier(dataframe, col_name):
    """
        This function checks dataframe has outlier or not.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    col_name : str
        The name of the column to be analyzed.
    Returns
    -------
    bool
        True if the dataframe has outlier, False otherwise.
    """

    lower_limit, upper_limit = outlier_thresholds(dataframe=dataframe, col_name=col_name)

    if dataframe[(dataframe[col_name] > upper_limit) | (dataframe[col_name] < lower_limit)].any(axis=None):
        # print(f'{col_name} have outlier')
        return True
    else:
        return False

def replace_with_thresholds(dataframe, variable, q1=0.05, q3=0.95):
    """
    This function replaces the outliers with the lower and upper limits.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    variable : str
        The name of the column to be analyzed.
    q1 : float, optional
        The default is 0.05.
    q3 : float, optional
        The default is 0.95.
    Returns
    -------
    None
    """

    low_limit, up_limit = outlier_thresholds(dataframe, variable, q1, q3)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

for col in num_cols:
    print(f"{col}: {check_outlier(df, col)}")

# Replace with thresholds
for col in num_cols:
    if check_outlier(df, col):
        replace_with_thresholds(df, col)

# Handle the outliers
for col in num_cols:
    print(f"{col}: {check_outlier(df, col)}")
# Out:
# X1_ACTUALPOSITION: False
# X1_ACTUALVELOCITY: True
# X1_ACTUALACCELERATION: True
# X1_COMMANDPOSITION: False
# X1_COMMANDVELOCITY: True
# X1_COMMANDACCELERATION: True
# X1_CURRENTFEEDBACK: True
# X1_DCBUSVOLTAGE: True
# X1_OUTPUTCURRENT: False
# X1_OUTPUTVOLTAGE: True
# X1_OUTPUTPOWER: True
# Y1_ACTUALPOSITION: False
# Y1_ACTUALVELOCITY: True
# Y1_ACTUALACCELERATION: True
# Y1_COMMANDPOSITION: False
# Y1_COMMANDVELOCITY: True
# Y1_COMMANDACCELERATION: True
# Y1_CURRENTFEEDBACK: True
# Y1_DCBUSVOLTAGE: True
# Y1_OUTPUTCURRENT: False
# Y1_OUTPUTVOLTAGE: True
# Y1_OUTPUTPOWER: True
# Z1_ACTUALPOSITION: False
# Z1_ACTUALVELOCITY: True
# Z1_ACTUALACCELERATION: True
# Z1_COMMANDPOSITION: False
# Z1_COMMANDVELOCITY: True
# Z1_COMMANDACCELERATION: True
# S1_ACTUALPOSITION: False
# S1_ACTUALVELOCITY: False
# S1_ACTUALACCELERATION: False
# S1_COMMANDPOSITION: False
# S1_COMMANDVELOCITY: False
# S1_CURRENTFEEDBACK: True
# S1_DCBUSVOLTAGE: True
# S1_OUTPUTCURRENT: True
# S1_OUTPUTVOLTAGE: False
# S1_OUTPUTPOWER: True
# M1_SEQUENCE_NUMBER: False
# FEEDRATE: False
# CLAMP_PRESSURE: False
# Z1_COMMANDVELOCITY: True
# Z1_COMMANDACCELERATION: True
# Z1_CURRENTFEEDBACK: False
# Z1_DCBUSVOLTAGE: False
# Z1_OUTPUTCURRENT: False
# Z1_OUTPUTVOLTAGE: False
# S1_COMMANDACCELERATION: True
# S1_SYSTEMINERTIA: False
# M1_CURRENT_FEEDRATE: False
# X1_ACTUALPOSITION: False
# X1_ACTUALVELOCITY: False
# X1_ACTUALACCELERATION: False
# X1_COMMANDPOSITION: False
# X1_COMMANDVELOCITY: False
# X1_COMMANDACCELERATION: False
# X1_CURRENTFEEDBACK: False
# X1_DCBUSVOLTAGE: False
# X1_OUTPUTCURRENT: False
# X1_OUTPUTVOLTAGE: False
# X1_OUTPUTPOWER: False
# Y1_ACTUALPOSITION: False
# Y1_ACTUALVELOCITY: False
# Y1_ACTUALACCELERATION: False
# Y1_COMMANDPOSITION: False
# Y1_COMMANDVELOCITY: False
# Y1_COMMANDACCELERATION: False
# Y1_CURRENTFEEDBACK: False
# Y1_DCBUSVOLTAGE: False
# Y1_OUTPUTCURRENT: False
# Y1_OUTPUTVOLTAGE: False
# Y1_OUTPUTPOWER: False
# Z1_ACTUALPOSITION: False
# Z1_ACTUALVELOCITY: False
# Z1_ACTUALACCELERATION: False
# Z1_COMMANDPOSITION: False
# Z1_COMMANDVELOCITY: False
# Z1_COMMANDACCELERATION: False
# S1_ACTUALPOSITION: False
# S1_ACTUALVELOCITY: False
# S1_ACTUALACCELERATION: False
# S1_COMMANDPOSITION: False
# S1_COMMANDVELOCITY: False
# S1_CURRENTFEEDBACK: False
# S1_DCBUSVOLTAGE: False
# S1_OUTPUTCURRENT: False
# S1_OUTPUTVOLTAGE: False
# S1_OUTPUTPOWER: False
# M1_SEQUENCE_NUMBER: False
# FEEDRATE: False
# CLAMP_PRESSURE: False
# Z1_COMMANDVELOCITY: False
# Z1_COMMANDACCELERATION: False
# Z1_CURRENTFEEDBACK: False
# Z1_DCBUSVOLTAGE: False
# Z1_OUTPUTCURRENT: False
# Z1_OUTPUTVOLTAGE: False
# S1_COMMANDACCELERATION: False
# S1_SYSTEMINERTIA: False
# M1_CURRENT_FEEDRATE: False

# %%
# 8. Missing Value Analysis
# No missing values in the dataset
print(df.isnull().sum())
# Out:
# X1_ACTUALPOSITION            0
# X1_ACTUALVELOCITY            0
# X1_ACTUALACCELERATION        0
# X1_COMMANDPOSITION           0
# X1_COMMANDVELOCITY           0
# X1_COMMANDACCELERATION       0
# X1_CURRENTFEEDBACK           0
# X1_DCBUSVOLTAGE              0
# X1_OUTPUTCURRENT             0
# X1_OUTPUTVOLTAGE             0
# X1_OUTPUTPOWER               0
# Y1_ACTUALPOSITION            0
# Y1_ACTUALVELOCITY            0
# Y1_ACTUALACCELERATION        0
# Y1_COMMANDPOSITION           0
# Y1_COMMANDVELOCITY           0
# Y1_COMMANDACCELERATION       0
# Y1_CURRENTFEEDBACK           0
# Y1_DCBUSVOLTAGE              0
# Y1_OUTPUTCURRENT             0
# Y1_OUTPUTVOLTAGE             0
# Y1_OUTPUTPOWER               0
# Z1_ACTUALPOSITION            0
# Z1_ACTUALVELOCITY            0
# Z1_ACTUALACCELERATION        0
# Z1_COMMANDPOSITION           0
# Z1_COMMANDVELOCITY           0
# Z1_COMMANDACCELERATION       0
# Z1_CURRENTFEEDBACK           0
# Z1_DCBUSVOLTAGE              0
# Z1_OUTPUTCURRENT             0
# Z1_OUTPUTVOLTAGE             0
# S1_ACTUALPOSITION            0
# S1_ACTUALVELOCITY            0
# S1_ACTUALACCELERATION        0
# S1_COMMANDPOSITION           0
# S1_COMMANDVELOCITY           0
# S1_COMMANDACCELERATION       0
# S1_CURRENTFEEDBACK           0
# S1_DCBUSVOLTAGE              0
# S1_OUTPUTCURRENT             0
# S1_OUTPUTVOLTAGE             0
# S1_OUTPUTPOWER               0
# S1_SYSTEMINERTIA             0
# M1_CURRENT_PROGRAM_NUMBER    0
# M1_SEQUENCE_NUMBER           0
# M1_CURRENT_FEEDRATE          0
# MACHINING_PROCESS            0
# FEEDRATE                     0
# CLAMP_PRESSURE               0
# TARGET                       0
# dtype: int64

# %%
# 9. Correlation Matrix
def high_correlated_cols(dataframe, plot=False, corr_th=0.90):
    """
    This function returns the columns that have a correlation higher than the threshold value.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    plot : bool, optional
        The default is False.
    corr_th : float, optional
        The default is 0.90.
    Returns
    -------
    drop_list : list
        The list of columns that have a correlation higher than the threshold value.
    """
    corr = dataframe.corr(numeric_only=True)
    cor_matrix = corr.abs()
    upper_triangle_matrix = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(bool))
    drop_list = [col for col in upper_triangle_matrix.columns if any(upper_triangle_matrix[col] > corr_th)]
    if plot:
        import seaborn as sns
        import matplotlib.pyplot as plt
        sns.set(rc={'figure.figsize': (15, 15)})
        sns.heatmap(corr, cmap="RdBu")
        plt.show()
    return drop_list

df_corr = df.corr(numeric_only=True)

#print
print("\nCorrelation matrix:")
print(df_corr)



# Plot correlation matrix

plt.figure(figsize=(14, 10))

plt.imshow(df_corr, aspect="auto")

plt.colorbar()

plt.xticks(
    range(len(df_corr.columns)),
    df_corr.columns,
    rotation=90
)

plt.yticks(
    range(len(df_corr.columns)),
    df_corr.columns
)

plt.title("Correlation Matrix")

plt.tight_layout()
plt.show()



drop_corr_list=high_correlated_cols(df, plot=False, corr_th=0.95) # 0.95 selected since it is meaningful in statisticaly
print(drop_corr_list)
# Out:
# Correlation matrix:
#                            X1_ACTUALPOSITION  X1_ACTUALVELOCITY  \
# X1_ACTUALPOSITION                   1.000000          -0.030941
# X1_ACTUALVELOCITY                  -0.030941           1.000000
# X1_ACTUALACCELERATION              -0.016689           0.030924
# X1_COMMANDPOSITION                  0.999897          -0.028638
# X1_COMMANDVELOCITY                 -0.033107           0.994133
# X1_COMMANDACCELERATION             -0.150383          -0.041841
# X1_CURRENTFEEDBACK                  0.075948           0.691661
# X1_DCBUSVOLTAGE                    -0.526051          -0.065583
# X1_OUTPUTCURRENT                    0.349605          -0.035358
# X1_OUTPUTVOLTAGE                   -0.297146          -0.074936
# X1_OUTPUTPOWER                     -0.105806          -0.130747
# Y1_ACTUALPOSITION                   0.888528           0.016290
# Y1_ACTUALVELOCITY                  -0.112884           0.203390
# Y1_ACTUALACCELERATION              -0.016427          -0.033419
# Y1_COMMANDPOSITION                  0.888413           0.016729
# Y1_COMMANDVELOCITY                 -0.113043           0.209099
# Y1_COMMANDACCELERATION             -0.058568           0.014647
# Y1_CURRENTFEEDBACK                 -0.131610          -0.047495
# Y1_DCBUSVOLTAGE                    -0.341505          -0.108209
# Y1_OUTPUTCURRENT                    0.500171          -0.002805
# Y1_OUTPUTVOLTAGE                   -0.133481          -0.229258
# Y1_OUTPUTPOWER                     -0.038788          -0.197926
# Z1_ACTUALPOSITION                   0.880043          -0.011045
# Z1_ACTUALVELOCITY                  -0.035531           0.241756
# Z1_ACTUALACCELERATION              -0.003497          -0.004640
# Z1_COMMANDPOSITION                  0.879920          -0.010573
# Z1_COMMANDVELOCITY                       NaN                NaN
# Z1_COMMANDACCELERATION                   NaN                NaN
# Z1_CURRENTFEEDBACK                       NaN                NaN
# Z1_DCBUSVOLTAGE                          NaN                NaN
# Z1_OUTPUTCURRENT                         NaN                NaN
# Z1_OUTPUTVOLTAGE                         NaN                NaN
# S1_ACTUALPOSITION                  -0.103477           0.008417
# S1_ACTUALVELOCITY                  -0.663605           0.078762
# S1_ACTUALACCELERATION               0.001704          -0.021332
# S1_COMMANDPOSITION                 -0.103584           0.008428
# S1_COMMANDVELOCITY                 -0.644630           0.076488
# S1_COMMANDACCELERATION             -0.014954          -0.022088
# S1_CURRENTFEEDBACK                 -0.594439           0.052583
# S1_DCBUSVOLTAGE                    -0.615841           0.053917
# S1_OUTPUTCURRENT                    0.530785          -0.040347
# S1_OUTPUTVOLTAGE                   -0.644873           0.075910
# S1_OUTPUTPOWER                     -0.626639           0.061478
# S1_SYSTEMINERTIA                         NaN                NaN
# M1_CURRENT_PROGRAM_NUMBER           0.016684           0.002372
# M1_SEQUENCE_NUMBER                 -0.408106           0.028422
# M1_CURRENT_FEEDRATE                 0.436281          -0.053616
# FEEDRATE                            0.453219          -0.023690
# CLAMP_PRESSURE                      0.108508          -0.018775
# TARGET                             -0.091920          -0.010880
#
#                            X1_ACTUALACCELERATION  X1_COMMANDPOSITION  \
# X1_ACTUALPOSITION                      -0.016689            0.999897
# X1_ACTUALVELOCITY                       0.030924           -0.028638
# X1_ACTUALACCELERATION                   1.000000           -0.016706
# X1_COMMANDPOSITION                     -0.016706            1.000000
# X1_COMMANDVELOCITY                      0.046164           -0.030793
# X1_COMMANDACCELERATION                  0.205882           -0.150428
# X1_CURRENTFEEDBACK                      0.049579            0.077517
# X1_DCBUSVOLTAGE                         0.042211           -0.526255
# X1_OUTPUTCURRENT                       -0.004859            0.349688
# X1_OUTPUTVOLTAGE                        0.038058           -0.297380
# X1_OUTPUTPOWER                          0.048713           -0.106244
# Y1_ACTUALPOSITION                      -0.006094            0.888720
# Y1_ACTUALVELOCITY                       0.003299           -0.112583
# Y1_ACTUALACCELERATION                  -0.105979           -0.016582
# Y1_COMMANDPOSITION                     -0.006070            0.888606
# Y1_COMMANDVELOCITY                      0.001638           -0.112727
# Y1_COMMANDACCELERATION                  0.004830           -0.058538
# Y1_CURRENTFEEDBACK                      0.010136           -0.131652
# Y1_DCBUSVOLTAGE                        -0.000590           -0.341641
# Y1_OUTPUTCURRENT                        0.010519            0.500264
# Y1_OUTPUTVOLTAGE                        0.004911           -0.133881
# Y1_OUTPUTPOWER                          0.014692           -0.039144
# Z1_ACTUALPOSITION                       0.005142            0.880197
# Z1_ACTUALVELOCITY                       0.006254           -0.034997
# Z1_ACTUALACCELERATION                  -0.014257           -0.003572
# Z1_COMMANDPOSITION                      0.005174            0.880076
# Z1_COMMANDVELOCITY                           NaN                 NaN
# Z1_COMMANDACCELERATION                       NaN                 NaN
# Z1_CURRENTFEEDBACK                           NaN                 NaN
# Z1_DCBUSVOLTAGE                              NaN                 NaN
# Z1_OUTPUTCURRENT                             NaN                 NaN
# Z1_OUTPUTVOLTAGE                             NaN                 NaN
# S1_ACTUALPOSITION                      -0.005648           -0.103486
# S1_ACTUALVELOCITY                      -0.014692           -0.663566
# S1_ACTUALACCELERATION                  -0.013398            0.001694
# S1_COMMANDPOSITION                     -0.005654           -0.103592
# S1_COMMANDVELOCITY                     -0.016589           -0.644593
# S1_COMMANDACCELERATION                 -0.001559           -0.015072
# S1_CURRENTFEEDBACK                     -0.014082           -0.594445
# S1_DCBUSVOLTAGE                        -0.017168           -0.615846
# S1_OUTPUTCURRENT                        0.012264            0.530807
# S1_OUTPUTVOLTAGE                       -0.016781           -0.644838
# S1_OUTPUTPOWER                         -0.014363           -0.626626
# S1_SYSTEMINERTIA                             NaN                 NaN
# M1_CURRENT_PROGRAM_NUMBER               0.001390            0.016690
# M1_SEQUENCE_NUMBER                     -0.009529           -0.408173
# M1_CURRENT_FEEDRATE                     0.025233            0.436145
# FEEDRATE                                0.021513            0.453153
# CLAMP_PRESSURE                          0.011194            0.108510
# TARGET                                  0.006983           -0.092029
#
#                            X1_COMMANDVELOCITY  X1_COMMANDACCELERATION  \
# X1_ACTUALPOSITION                   -0.033107               -0.150383
# X1_ACTUALVELOCITY                    0.994133               -0.041841
# X1_ACTUALACCELERATION                0.046164                0.205882
# X1_COMMANDPOSITION                  -0.030793               -0.150428
# X1_COMMANDVELOCITY                   1.000000                0.006160
# X1_COMMANDACCELERATION               0.006160                1.000000
# X1_CURRENTFEEDBACK                   0.711162                0.031428
# X1_DCBUSVOLTAGE                     -0.061236                0.040424
# X1_OUTPUTCURRENT                    -0.036467               -0.038568
# X1_OUTPUTVOLTAGE                    -0.072982                0.028510
# X1_OUTPUTPOWER                      -0.125883                0.036244
# Y1_ACTUALPOSITION                    0.015839               -0.021257
# Y1_ACTUALVELOCITY                    0.203356                0.003885
# Y1_ACTUALACCELERATION               -0.036114                0.001660
# Y1_COMMANDPOSITION                   0.016274               -0.021267
# Y1_COMMANDVELOCITY                   0.208259               -0.003006
# Y1_COMMANDACCELERATION               0.008464                0.179914
# Y1_CURRENTFEEDBACK                  -0.047967                0.009870
# Y1_DCBUSVOLTAGE                     -0.106153                0.040457
# Y1_OUTPUTCURRENT                    -0.003699               -0.032351
# Y1_OUTPUTVOLTAGE                    -0.227692                0.036125
# Y1_OUTPUTPOWER                      -0.196441                0.047125
# Z1_ACTUALPOSITION                   -0.012047               -0.022102
# Z1_ACTUALVELOCITY                    0.240075                0.001515
# Z1_ACTUALACCELERATION               -0.003231                0.012166
# Z1_COMMANDPOSITION                  -0.011576               -0.022099
# Z1_COMMANDVELOCITY                        NaN                     NaN
# Z1_COMMANDACCELERATION                    NaN                     NaN
# Z1_CURRENTFEEDBACK                        NaN                     NaN
# Z1_DCBUSVOLTAGE                           NaN                     NaN
# Z1_OUTPUTCURRENT                          NaN                     NaN
# Z1_OUTPUTVOLTAGE                          NaN                     NaN
# S1_ACTUALPOSITION                    0.007460               -0.005118
# S1_ACTUALVELOCITY                    0.079494                0.021428
# S1_ACTUALACCELERATION               -0.021577               -0.001535
# S1_COMMANDPOSITION                   0.007471               -0.005118
# S1_COMMANDVELOCITY                   0.077405                0.021843
# S1_COMMANDACCELERATION              -0.023042               -0.002421
# S1_CURRENTFEEDBACK                   0.052659                0.022230
# S1_DCBUSVOLTAGE                      0.054002                0.020908
# S1_OUTPUTCURRENT                    -0.041120               -0.024701
# S1_OUTPUTVOLTAGE                     0.076789                0.021894
# S1_OUTPUTPOWER                       0.062302                0.023535
# S1_SYSTEMINERTIA                          NaN                     NaN
# M1_CURRENT_PROGRAM_NUMBER            0.003105                0.000727
# M1_SEQUENCE_NUMBER                   0.027949               -0.000620
# M1_CURRENT_FEEDRATE                 -0.053498               -0.006793
# FEEDRATE                            -0.022472                0.018989
# CLAMP_PRESSURE                      -0.018981                0.009716
# TARGET                              -0.011573                0.004172
#
#                            X1_CURRENTFEEDBACK  X1_DCBUSVOLTAGE  \
# X1_ACTUALPOSITION                    0.075948        -0.526051
# X1_ACTUALVELOCITY                    0.691661        -0.065583
# X1_ACTUALACCELERATION                0.049579         0.042211
# X1_COMMANDPOSITION                   0.077517        -0.526255
# X1_COMMANDVELOCITY                   0.711162        -0.061236
# X1_COMMANDACCELERATION               0.031428         0.040424
# X1_CURRENTFEEDBACK                   1.000000        -0.017293
# X1_DCBUSVOLTAGE                     -0.017293         1.000000
# X1_OUTPUTCURRENT                    -0.076098        -0.440002
# X1_OUTPUTVOLTAGE                    -0.016464         0.768037
# X1_OUTPUTPOWER                      -0.026813         0.656959
# Y1_ACTUALPOSITION                    0.045318        -0.515159
# Y1_ACTUALVELOCITY                   -0.002758        -0.132681
# Y1_ACTUALACCELERATION               -0.015080        -0.013110
# Y1_COMMANDPOSITION                   0.045387        -0.515406
# Y1_COMMANDVELOCITY                  -0.000572        -0.137218
# Y1_COMMANDACCELERATION              -0.008632         0.014649
# Y1_CURRENTFEEDBACK                  -0.250501        -0.068411
# Y1_DCBUSVOLTAGE                      0.000965         0.419926
# Y1_OUTPUTCURRENT                    -0.047167        -0.535732
# Y1_OUTPUTVOLTAGE                    -0.056454         0.337458
# Y1_OUTPUTPOWER                      -0.049752         0.223452
# Z1_ACTUALPOSITION                   -0.028215        -0.612691
# Z1_ACTUALVELOCITY                    0.050005         0.018332
# Z1_ACTUALACCELERATION               -0.009456         0.021929
# Z1_COMMANDPOSITION                  -0.028095        -0.612947
# Z1_COMMANDVELOCITY                        NaN              NaN
# Z1_COMMANDACCELERATION                    NaN              NaN
# Z1_CURRENTFEEDBACK                        NaN              NaN
# Z1_DCBUSVOLTAGE                           NaN              NaN
# Z1_OUTPUTCURRENT                          NaN              NaN
# Z1_OUTPUTVOLTAGE                          NaN              NaN
# S1_ACTUALPOSITION                    0.006321         0.089819
# S1_ACTUALVELOCITY                    0.104576         0.555981
# S1_ACTUALACCELERATION               -0.009116         0.014074
# S1_COMMANDPOSITION                   0.006329         0.089914
# S1_COMMANDVELOCITY                   0.108960         0.556048
# S1_COMMANDACCELERATION              -0.013984         0.009079
# S1_CURRENTFEEDBACK                   0.090905         0.514710
# S1_DCBUSVOLTAGE                      0.092608         0.531699
# S1_OUTPUTCURRENT                    -0.078877        -0.524784
# S1_OUTPUTVOLTAGE                     0.108388         0.556337
# S1_OUTPUTPOWER                       0.097353         0.547260
# S1_SYSTEMINERTIA                          NaN              NaN
# M1_CURRENT_PROGRAM_NUMBER            0.000687        -0.014304
# M1_SEQUENCE_NUMBER                   0.047563         0.345501
# M1_CURRENT_FEEDRATE                 -0.107745        -0.425185
# FEEDRATE                            -0.015090        -0.269666
# CLAMP_PRESSURE                      -0.013575        -0.045534
# TARGET                              -0.020942         0.077357
#
#                            X1_OUTPUTCURRENT  X1_OUTPUTVOLTAGE  ...  \
# X1_ACTUALPOSITION                  0.349605         -0.297146  ...
# X1_ACTUALVELOCITY                 -0.035358         -0.074936  ...
# X1_ACTUALACCELERATION             -0.004859          0.038058  ...
# X1_COMMANDPOSITION                 0.349688         -0.297380  ...
# X1_COMMANDVELOCITY                -0.036467         -0.072982  ...
# X1_COMMANDACCELERATION            -0.038568          0.028510  ...
# X1_CURRENTFEEDBACK                -0.076098         -0.016464  ...
# X1_DCBUSVOLTAGE                   -0.440002          0.768037  ...
# X1_OUTPUTCURRENT                   1.000000         -0.429552  ...
# X1_OUTPUTVOLTAGE                  -0.429552          1.000000  ...
# X1_OUTPUTPOWER                    -0.375185          0.916014  ...
# Y1_ACTUALPOSITION                  0.360896         -0.300052  ...
# Y1_ACTUALVELOCITY                 -0.048896         -0.252902  ...
# Y1_ACTUALACCELERATION             -0.014186         -0.009935  ...
# Y1_COMMANDPOSITION                 0.360820         -0.300478  ...
# Y1_COMMANDVELOCITY                -0.051766         -0.256608  ...
# Y1_COMMANDACCELERATION            -0.042549          0.030729  ...
# Y1_CURRENTFEEDBACK                -0.012310         -0.111022  ...
# Y1_DCBUSVOLTAGE                   -0.316880          0.351079  ...
# Y1_OUTPUTCURRENT                   0.798668         -0.439183  ...
# Y1_OUTPUTVOLTAGE                  -0.233737          0.460721  ...
# Y1_OUTPUTPOWER                    -0.216502          0.394147  ...
# Z1_ACTUALPOSITION                  0.492225         -0.344548  ...
# Z1_ACTUALVELOCITY                 -0.063524         -0.143126  ...
# Z1_ACTUALACCELERATION             -0.028159         -0.030843  ...
# Z1_COMMANDPOSITION                 0.492080         -0.345001  ...
# Z1_COMMANDVELOCITY                      NaN               NaN  ...
# Z1_COMMANDACCELERATION                  NaN               NaN  ...
# Z1_CURRENTFEEDBACK                      NaN               NaN  ...
# Z1_DCBUSVOLTAGE                         NaN               NaN  ...
# Z1_OUTPUTCURRENT                        NaN               NaN  ...
# Z1_OUTPUTVOLTAGE                        NaN               NaN  ...
# S1_ACTUALPOSITION                 -0.093464          0.068518  ...
# S1_ACTUALVELOCITY                 -0.587531          0.304345  ...
# S1_ACTUALACCELERATION             -0.029882         -0.004422  ...
# S1_COMMANDPOSITION                -0.093562          0.068572  ...
# S1_COMMANDVELOCITY                -0.596049          0.307827  ...
# S1_COMMANDACCELERATION            -0.046790          0.014511  ...
# S1_CURRENTFEEDBACK                -0.578973          0.297941  ...
# S1_DCBUSVOLTAGE                   -0.603326          0.308500  ...
# S1_OUTPUTCURRENT                   0.727447         -0.310773  ...
# S1_OUTPUTVOLTAGE                  -0.599540          0.309724  ...
# S1_OUTPUTPOWER                    -0.611868          0.316659  ...
# S1_SYSTEMINERTIA                        NaN               NaN  ...
# M1_CURRENT_PROGRAM_NUMBER          0.043361         -0.005076  ...
# M1_SEQUENCE_NUMBER                -0.367667          0.175653  ...
# M1_CURRENT_FEEDRATE                0.382719         -0.140476  ...
# FEEDRATE                          -0.172817          0.024928  ...
# CLAMP_PRESSURE                    -0.308918          0.059563  ...
# TARGET                            -0.080973          0.076638  ...
#
#                            S1_OUTPUTCURRENT  S1_OUTPUTVOLTAGE  S1_OUTPUTPOWER  \
# X1_ACTUALPOSITION                  0.530785         -0.644873       -0.626639
# X1_ACTUALVELOCITY                 -0.040347          0.075910        0.061478
# X1_ACTUALACCELERATION              0.012264         -0.016781       -0.014363
# X1_COMMANDPOSITION                 0.530807         -0.644838       -0.626626
# X1_COMMANDVELOCITY                -0.041120          0.076789        0.062302
# X1_COMMANDACCELERATION            -0.024701          0.021894        0.023535
# X1_CURRENTFEEDBACK                -0.078877          0.108388        0.097353
# X1_DCBUSVOLTAGE                   -0.524784          0.556337        0.547260
# X1_OUTPUTCURRENT                   0.727447         -0.599540       -0.611868
# X1_OUTPUTVOLTAGE                  -0.310773          0.309724        0.316659
# X1_OUTPUTPOWER                    -0.187288          0.119031        0.136086
# Y1_ACTUALPOSITION                  0.563849         -0.667213       -0.650937
# Y1_ACTUALVELOCITY                 -0.094578          0.125697        0.123273
# Y1_ACTUALACCELERATION             -0.000880          0.019522        0.018581
# Y1_COMMANDPOSITION                 0.563711         -0.667051       -0.650777
# Y1_COMMANDVELOCITY                -0.097521          0.127982        0.125970
# Y1_COMMANDACCELERATION            -0.036722          0.024453        0.028699
# Y1_CURRENTFEEDBACK                -0.023258          0.032579        0.035662
# Y1_DCBUSVOLTAGE                   -0.383249          0.446204        0.426597
# Y1_OUTPUTCURRENT                   0.754323         -0.661117       -0.664888
# Y1_OUTPUTVOLTAGE                  -0.161010          0.161452        0.157230
# Y1_OUTPUTPOWER                    -0.086762          0.033675        0.037240
# Z1_ACTUALPOSITION                  0.722752         -0.879985       -0.853800
# Z1_ACTUALVELOCITY                 -0.053212          0.049466        0.044183
# Z1_ACTUALACCELERATION             -0.085997         -0.012160       -0.008021
# Z1_COMMANDPOSITION                 0.722628         -0.879862       -0.853682
# Z1_COMMANDVELOCITY                      NaN               NaN             NaN
# Z1_COMMANDACCELERATION                  NaN               NaN             NaN
# Z1_CURRENTFEEDBACK                      NaN               NaN             NaN
# Z1_DCBUSVOLTAGE                         NaN               NaN             NaN
# Z1_OUTPUTCURRENT                        NaN               NaN             NaN
# Z1_OUTPUTVOLTAGE                        NaN               NaN             NaN
# S1_ACTUALPOSITION                 -0.115117          0.164093        0.151862
# S1_ACTUALVELOCITY                 -0.811143          0.989567        0.954624
# S1_ACTUALACCELERATION             -0.104468          0.013984       -0.053322
# S1_COMMANDPOSITION                -0.115257          0.164252        0.152016
# S1_COMMANDVELOCITY                -0.819341          0.999298        0.964764
# S1_COMMANDACCELERATION            -0.058421         -0.001785        0.042799
# S1_CURRENTFEEDBACK                -0.789766          0.902629        0.946269
# S1_DCBUSVOLTAGE                   -0.824628          0.934989        0.979337
# S1_OUTPUTCURRENT                   1.000000         -0.819285       -0.835290
# S1_OUTPUTVOLTAGE                  -0.819285          1.000000        0.965748
# S1_OUTPUTPOWER                    -0.835290          0.965748        1.000000
# S1_SYSTEMINERTIA                        NaN               NaN             NaN
# M1_CURRENT_PROGRAM_NUMBER          0.044521         -0.014263       -0.013753
# M1_SEQUENCE_NUMBER                -0.515596          0.643384        0.613977
# M1_CURRENT_FEEDRATE                0.653337         -0.834502       -0.803365
# FEEDRATE                           0.256963         -0.474265       -0.439092
# CLAMP_PRESSURE                    -0.038751         -0.112622       -0.089011
# TARGET                            -0.054990          0.019141        0.017414
#
#                            S1_SYSTEMINERTIA  M1_CURRENT_PROGRAM_NUMBER  \
# X1_ACTUALPOSITION                       NaN                   0.016684
# X1_ACTUALVELOCITY                       NaN                   0.002372
# X1_ACTUALACCELERATION                   NaN                   0.001390
# X1_COMMANDPOSITION                      NaN                   0.016690
# X1_COMMANDVELOCITY                      NaN                   0.003105
# X1_COMMANDACCELERATION                  NaN                   0.000727
# X1_CURRENTFEEDBACK                      NaN                   0.000687
# X1_DCBUSVOLTAGE                         NaN                  -0.014304
# X1_OUTPUTCURRENT                        NaN                   0.043361
# X1_OUTPUTVOLTAGE                        NaN                  -0.005076
# X1_OUTPUTPOWER                          NaN                  -0.001767
# Y1_ACTUALPOSITION                       NaN                   0.016517
# Y1_ACTUALVELOCITY                       NaN                  -0.005926
# Y1_ACTUALACCELERATION                   NaN                   0.001635
# Y1_COMMANDPOSITION                      NaN                   0.016505
# Y1_COMMANDVELOCITY                      NaN                  -0.005983
# Y1_COMMANDACCELERATION                  NaN                   0.000756
# Y1_CURRENTFEEDBACK                      NaN                  -0.005406
# Y1_DCBUSVOLTAGE                         NaN                  -0.007889
# Y1_OUTPUTCURRENT                        NaN                   0.076555
# Y1_OUTPUTVOLTAGE                        NaN                  -0.000718
# Y1_OUTPUTPOWER                          NaN                   0.003805
# Z1_ACTUALPOSITION                       NaN                   0.017156
# Z1_ACTUALVELOCITY                       NaN                   0.002476
# Z1_ACTUALACCELERATION                   NaN                  -0.002082
# Z1_COMMANDPOSITION                      NaN                   0.017161
# Z1_COMMANDVELOCITY                      NaN                        NaN
# Z1_COMMANDACCELERATION                  NaN                        NaN
# Z1_CURRENTFEEDBACK                      NaN                        NaN
# Z1_DCBUSVOLTAGE                         NaN                        NaN
# Z1_OUTPUTCURRENT                        NaN                        NaN
# Z1_OUTPUTVOLTAGE                        NaN                        NaN
# S1_ACTUALPOSITION                       NaN                  -0.030746
# S1_ACTUALVELOCITY                       NaN                  -0.013207
# S1_ACTUALACCELERATION                   NaN                  -0.002558
# S1_COMMANDPOSITION                      NaN                  -0.030748
# S1_COMMANDVELOCITY                      NaN                  -0.014136
# S1_COMMANDACCELERATION                  NaN                  -0.000138
# S1_CURRENTFEEDBACK                      NaN                  -0.017858
# S1_DCBUSVOLTAGE                         NaN                  -0.014504
# S1_OUTPUTCURRENT                        NaN                   0.044521
# S1_OUTPUTVOLTAGE                        NaN                  -0.014263
# S1_OUTPUTPOWER                          NaN                  -0.013753
# S1_SYSTEMINERTIA                        NaN                        NaN
# M1_CURRENT_PROGRAM_NUMBER               NaN                   1.000000
# M1_SEQUENCE_NUMBER                      NaN                  -0.010649
# M1_CURRENT_FEEDRATE                     NaN                   0.016810
# FEEDRATE                                NaN                   0.020581
# CLAMP_PRESSURE                          NaN                   0.010117
# TARGET                                  NaN                  -0.010390
#
#                            M1_SEQUENCE_NUMBER  M1_CURRENT_FEEDRATE  FEEDRATE  \
# X1_ACTUALPOSITION                   -0.408106             0.436281  0.453219
# X1_ACTUALVELOCITY                    0.028422            -0.053616 -0.023690
# X1_ACTUALACCELERATION               -0.009529             0.025233  0.021513
# X1_COMMANDPOSITION                  -0.408173             0.436145  0.453153
# X1_COMMANDVELOCITY                   0.027949            -0.053498 -0.022472
# X1_COMMANDACCELERATION              -0.000620            -0.006793  0.018989
# X1_CURRENTFEEDBACK                   0.047563            -0.107745 -0.015090
# X1_DCBUSVOLTAGE                      0.345501            -0.425185 -0.269666
# X1_OUTPUTCURRENT                    -0.367667             0.382719 -0.172817
# X1_OUTPUTVOLTAGE                     0.175653            -0.140476  0.024928
# X1_OUTPUTPOWER                       0.053610             0.036744  0.221902
# Y1_ACTUALPOSITION                   -0.433552             0.459484  0.455543
# Y1_ACTUALVELOCITY                    0.034848            -0.154846 -0.019277
# Y1_ACTUALACCELERATION                0.007463            -0.015363  0.004653
# Y1_COMMANDPOSITION                  -0.433520             0.459270  0.455564
# Y1_COMMANDVELOCITY                   0.036240            -0.155590 -0.016113
# Y1_COMMANDACCELERATION              -0.001574            -0.007946  0.027240
# Y1_CURRENTFEEDBACK                  -0.046253            -0.033121 -0.005768
# Y1_DCBUSVOLTAGE                      0.288917            -0.356687 -0.208803
# Y1_OUTPUTCURRENT                    -0.403990             0.486160  0.106989
# Y1_OUTPUTVOLTAGE                     0.096751            -0.060049  0.018920
# Y1_OUTPUTPOWER                       0.013149             0.085979  0.176451
# Z1_ACTUALPOSITION                   -0.580224             0.698981  0.524826
# Z1_ACTUALVELOCITY                    0.034036            -0.027154  0.025138
# Z1_ACTUALACCELERATION                0.012473             0.012814  0.043326
# Z1_COMMANDPOSITION                  -0.580120             0.698982  0.524860
# Z1_COMMANDVELOCITY                        NaN                  NaN       NaN
# Z1_COMMANDACCELERATION                    NaN                  NaN       NaN
# Z1_CURRENTFEEDBACK                        NaN                  NaN       NaN
# Z1_DCBUSVOLTAGE                           NaN                  NaN       NaN
# Z1_OUTPUTCURRENT                          NaN                  NaN       NaN
# Z1_OUTPUTVOLTAGE                          NaN                  NaN       NaN
# S1_ACTUALPOSITION                    0.126999            -0.128359 -0.099861
# S1_ACTUALVELOCITY                    0.642461            -0.822984 -0.477213
# S1_ACTUALACCELERATION                0.011036            -0.024511 -0.011842
# S1_COMMANDPOSITION                   0.127119            -0.128489 -0.099933
# S1_COMMANDVELOCITY                   0.644489            -0.835581 -0.477036
# S1_COMMANDACCELERATION              -0.029553            -0.002661  0.012271
# S1_CURRENTFEEDBACK                   0.565000            -0.756666 -0.414328
# S1_DCBUSVOLTAGE                      0.590039            -0.780916 -0.424003
# S1_OUTPUTCURRENT                    -0.515596             0.653337  0.256963
# S1_OUTPUTVOLTAGE                     0.643384            -0.834502 -0.474265
# S1_OUTPUTPOWER                       0.613977            -0.803365 -0.439092
# S1_SYSTEMINERTIA                          NaN                  NaN       NaN
# M1_CURRENT_PROGRAM_NUMBER           -0.010649             0.016810  0.020581
# M1_SEQUENCE_NUMBER                   1.000000            -0.542391 -0.331306
# M1_CURRENT_FEEDRATE                 -0.542391             1.000000  0.530966
# FEEDRATE                            -0.331306             0.530966  1.000000
# CLAMP_PRESSURE                      -0.067312             0.224498  0.382278
# TARGET                               0.015939             0.061106  0.049609
#
#                            CLAMP_PRESSURE    TARGET
# X1_ACTUALPOSITION                0.108508 -0.091920
# X1_ACTUALVELOCITY               -0.018775 -0.010880
# X1_ACTUALACCELERATION            0.011194  0.006983
# X1_COMMANDPOSITION               0.108510 -0.092029
# X1_COMMANDVELOCITY              -0.018981 -0.011573
# X1_COMMANDACCELERATION           0.009716  0.004172
# X1_CURRENTFEEDBACK              -0.013575 -0.020942
# X1_DCBUSVOLTAGE                 -0.045534  0.077357
# X1_OUTPUTCURRENT                -0.308918 -0.080973
# X1_OUTPUTVOLTAGE                 0.059563  0.076638
# X1_OUTPUTPOWER                   0.122262  0.075907
# Y1_ACTUALPOSITION                0.107970 -0.090862
# Y1_ACTUALVELOCITY               -0.022284 -0.012706
# Y1_ACTUALACCELERATION            0.001178 -0.005939
# Y1_COMMANDPOSITION               0.107963 -0.090920
# Y1_COMMANDVELOCITY              -0.020407 -0.012364
# Y1_COMMANDACCELERATION           0.014558  0.006690
# Y1_CURRENTFEEDBACK              -0.009423 -0.004987
# Y1_DCBUSVOLTAGE                 -0.043340  0.050998
# Y1_OUTPUTCURRENT                -0.153976 -0.176805
# Y1_OUTPUTVOLTAGE                 0.034723  0.057565
# Y1_OUTPUTPOWER                   0.093696  0.061434
# Z1_ACTUALPOSITION                0.128033 -0.064627
# Z1_ACTUALVELOCITY               -0.002301 -0.007570
# Z1_ACTUALACCELERATION            0.012651  0.014468
# Z1_COMMANDPOSITION               0.128035 -0.064638
# Z1_COMMANDVELOCITY                    NaN       NaN
# Z1_COMMANDACCELERATION                NaN       NaN
# Z1_CURRENTFEEDBACK                    NaN       NaN
# Z1_DCBUSVOLTAGE                       NaN       NaN
# Z1_OUTPUTCURRENT                      NaN       NaN
# Z1_OUTPUTVOLTAGE                      NaN       NaN
# S1_ACTUALPOSITION               -0.095431  0.007011
# S1_ACTUALVELOCITY               -0.118905  0.021777
# S1_ACTUALACCELERATION           -0.005658 -0.011138
# S1_COMMANDPOSITION              -0.095450  0.007017
# S1_COMMANDVELOCITY              -0.117498  0.019994
# S1_COMMANDACCELERATION           0.002980  0.008443
# S1_CURRENTFEEDBACK              -0.092794  0.022292
# S1_DCBUSVOLTAGE                 -0.086516  0.018178
# S1_OUTPUTCURRENT                -0.038751 -0.054990
# S1_OUTPUTVOLTAGE                -0.112622  0.019141
# S1_OUTPUTPOWER                  -0.089011  0.017414
# S1_SYSTEMINERTIA                      NaN       NaN
# M1_CURRENT_PROGRAM_NUMBER        0.010117 -0.010390
# M1_SEQUENCE_NUMBER              -0.067312  0.015939
# M1_CURRENT_FEEDRATE              0.224498  0.061106
# FEEDRATE                         0.382278  0.049609
# CLAMP_PRESSURE                   1.000000  0.091851
# TARGET                           0.091851  1.000000
#
# [50 rows x 50 columns]
# ['X1_COMMANDPOSITION', 'X1_COMMANDVELOCITY', 'Y1_COMMANDPOSITION', 'Y1_COMMANDVELOCITY', 'Z1_COMMANDPOSITION', 'S1_COMMANDPOSITION', 'S1_COMMANDVELOCITY', 'S1_DCBUSVOLTAGE', 'S1_OUTPUTVOLTAGE', 'S1_OUTPUTPOWER']

# %%
# Drop List
"""
['X1_COMMANDPOSITION', 'X1_COMMANDVELOCITY', 'Y1_COMMANDPOSITION',
'Y1_COMMANDVELOCITY', 'Z1_COMMANDPOSITION', 'S1_COMMANDPOSITION',
'S1_COMMANDVELOCITY', 'S1_DCBUSVOLTAGE', 'S1_OUTPUTVOLTAGE', 'S1_OUTPUTPOWER']
"""
# Out:
# "\n['X1_COMMANDPOSITION', 'X1_COMMANDVELOCITY', 'Y1_COMMANDPOSITION',\n'Y1_COMMANDVELOCITY', 'Z1_COMMANDPOSITION', 'S1_COMMANDPOSITION',\n'S1_COMMANDVELOCITY', 'S1_DCBUSVOLTAGE', 'S1_OUTPUTVOLTAGE', 'S1_OUTPUTPOWER']\n"

# %%
print(df.shape) # (25286, 41)
# df.drop(drop_corr_list, axis=1, inplace=True)
print(df.shape) # (25286, 31)
# Out:
# (25286, 51)
# (25286, 51)

# %%
# ==========================================================
# 14. WORN VS UNWORN COMPARISON
# ==========================================================

# Recompute numeric columns fresh, since df's column names changed
# (uppercased) after earlier cells ran df.columns = df.columns.str.upper()
numeric_columns = df.select_dtypes(include=np.number).columns.tolist()

# Select numerical columns except target itself
features = [
    column
    for column in numeric_columns
    if column != "TARGET"
]

for column in features:

    plt.figure(figsize=(7, 4))

    df.boxplot(
        column=column,
        by="TARGET"
    )

    plt.title(f"{column}: Worn vs Unworn")
    plt.suptitle("")

    plt.xlabel("Tool Condition")
    plt.ylabel(column)

    plt.tight_layout()
    plt.show()

# %%
# ==========================================================
# 18. FINAL SUMMARY
# ==========================================================

print("\n" + "=" * 60)
print("EDA COMPLETED")
print("=" * 60)

print("\nFinal dataset shape:", df.shape)

print("\nTarget distribution:")
print(df["TARGET"].value_counts())

print("\nTotal missing values:",
      df.isnull().sum().sum())

print("\nTotal duplicate rows:",
      df.duplicated().sum())
# Out:
# ============================================================
# EDA COMPLETED
# ============================================================
#
# Final dataset shape: (25286, 51)
#
# Target distribution:
# TARGET
# 1    13308
# 0    11978
# Name: count, dtype: int64
#
# Total missing values: 0
#
# Total duplicate rows: 331

# %%
#######################################
######### FEATURE ENGINEERING #########
#######################################

# There are 6 steps to be taken in the Feature Engineering process.
# 1. Missing Values
# 2. Outlier Values Analysis
# 3. Feature Generation
# 4. Encoding
# 5. Standardization
# 6. Save the Dataset

# 1. Missing Values
# No missing values in the dataset

# 2. Outlier Values Analysis
# Outliers are handled in the previous steps

# 3. Feature Generation
# It will be implemanted lately after research.

# 4. Encoding
# No need for encoding, there is only one categorical variable (TARGET)
# It is already converted to binary at line 59 --> for with drop_list

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

cat_cols, num_cols, cat_but_car = grap_column_names(df)

for col in cat_cols:
    cat_cols = [col for col in cat_cols if col not in cat_to_numeric]

for col in cat_to_numeric:
    num_cols.append(col)


cat_cols = [col for col in cat_cols if col not in ["TARGET"]]
print(cat_cols)

def one_hot_encoder(dataframe, categorical_columns, drop_first=True):
    """
    This function encodes the categorical variables to numericals.

    Parameters
    ----------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    categorical_columns : list
        The name of the column to be encoded.
    drop_first : bool, optional
        Dummy trap. The default is True.
    Returns
    -------
    dataframe : pandas dataframe
        The dataframe to be analyzed.
    """
    dataframe = pd.get_dummies(dataframe, columns=categorical_columns, drop_first=drop_first)
    return dataframe

df = one_hot_encoder(df, cat_cols, drop_first=True)

print(df.head())

# 5. Standardization

scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

print('#'*50)

print(df.head())
print(df.shape)
print(cat_cols)

# 6. Save the Dataset
df.to_csv('aggregated_cleaned.csv', index=False)

# Shuffle dataset
df = df.sample(frac=1).reset_index(drop=True)

# Save train and test sets
test_size = int(0.2 * df.shape[0])
test_data = df[:test_size]
train_data = df[test_size:]

train_data.to_csv('aggregated_train_cleaned.csv', index=False)
print("Train dataset shape: ",train_data.shape)

print("#"*50)

test_data.to_csv('aggregated_test_cleaned.csv', index=False)
print("Test dataset shape: ",test_data.shape)
# Out:
# Observations: 25286
# Variables: 61
# categorical_cols: 24
# num_cols: 37
# categorical_but_cardinal: 0
# numeric_but_categorical: 24
# ['MACHINING_PROCESS_Layer 1 Down', 'MACHINING_PROCESS_Layer 1 Up', 'MACHINING_PROCESS_Layer 2 Down', 'MACHINING_PROCESS_Layer 2 Up', 'MACHINING_PROCESS_Layer 3 Down', 'MACHINING_PROCESS_Layer 3 Up', 'MACHINING_PROCESS_Prep', 'MACHINING_PROCESS_Repositioning', 'MACHINING_PROCESS_Starting', 'MACHINING_PROCESS_end', 'M1_CURRENT_PROGRAM_NUMBER_1.0', 'M1_CURRENT_PROGRAM_NUMBER_4.0']
#    X1_ACTUALPOSITION  X1_ACTUALVELOCITY  X1_ACTUALACCELERATION  \
# 0              198.0                0.0                   0.00
# 1              198.0              -10.8                -350.00
# 2              196.0              -17.8                  -6.25
# 3              194.0              -18.0                   0.00
# 4              193.0              -17.9                 -18.80
#
#    X1_COMMANDPOSITION  X1_COMMANDVELOCITY  X1_COMMANDACCELERATION  \
# 0               198.0                 0.0                0.000000
# 1               198.0               -13.6              -11.608750
# 2               196.0               -17.9               -0.000095
# 3               194.0               -17.9               -0.000095
# 4               192.0               -17.9                0.000095
#
#    X1_CURRENTFEEDBACK  X1_DCBUSVOLTAGE  X1_OUTPUTCURRENT  X1_OUTPUTVOLTAGE  \
# 0                0.18           0.0207             329.0              2.77
# 1              -10.90           0.1860             328.0             23.30
# 2               -8.59           0.1400             328.0             30.60
# 3               -6.11           0.1300             327.0             30.30
# 4               -5.70           0.1140             328.0             30.50
#
#    ...  MACHINING_PROCESS_Layer 2 Down_True  \
# 0  ...                                False
# 1  ...                                False
# 2  ...                                False
# 3  ...                                False
# 4  ...                                False
#
#    MACHINING_PROCESS_Layer 2 Up_True  MACHINING_PROCESS_Layer 3 Down_True  \
# 0                              False                                False
# 1                              False                                False
# 2                              False                                False
# 3                              False                                False
# 4                              False                                False
#
#    MACHINING_PROCESS_Layer 3 Up_True  MACHINING_PROCESS_Prep_True  \
# 0                              False                        False
# 1                              False                         True
# 2                              False                         True
# 3                              False                         True
# 4                              False                         True
#
#    MACHINING_PROCESS_Repositioning_True  MACHINING_PROCESS_Starting_True  \
# 0                                 False                             True
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
#
#    MACHINING_PROCESS_end_True  M1_CURRENT_PROGRAM_NUMBER_1.0_True  \
# 0                       False                                True
# 1                       False                                True
# 2                       False                                True
# 3                       False                                True
# 4                       False                                True
#
#    M1_CURRENT_PROGRAM_NUMBER_4.0_True
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
# [5 rows x 61 columns]
# ##################################################
#    X1_ACTUALPOSITION  X1_ACTUALVELOCITY  X1_ACTUALACCELERATION  \
# 0           1.000000           0.459253               0.500000
# 1           1.000000           0.216119               0.000000
# 2           0.964912           0.058532               0.491071
# 3           0.929825           0.054030               0.500000
# 4           0.912281           0.056281               0.473143
#
#    X1_COMMANDPOSITION  X1_COMMANDVELOCITY  X1_COMMANDACCELERATION  \
# 0            1.000000            0.454545                0.487968
# 1            1.000000            0.145455                0.000000
# 2            0.964912            0.047727                0.487964
# 3            0.929825            0.047727                0.487964
# 4            0.894737            0.047727                0.487972
#
#    X1_CURRENTFEEDBACK  X1_DCBUSVOLTAGE  X1_OUTPUTCURRENT  X1_OUTPUTVOLTAGE  \
# 0            0.492481         0.070769          0.818182          0.044677
# 1            0.261069         0.635897          0.727273          0.375806
# 2            0.309315         0.478632          0.727273          0.493548
# 3            0.361111         0.444444          0.636364          0.488710
# 4            0.369674         0.389744          0.727273          0.491935
#
#    ...  MACHINING_PROCESS_Layer 2 Down_True  \
# 0  ...                                False
# 1  ...                                False
# 2  ...                                False
# 3  ...                                False
# 4  ...                                False
#
#    MACHINING_PROCESS_Layer 2 Up_True  MACHINING_PROCESS_Layer 3 Down_True  \
# 0                              False                                False
# 1                              False                                False
# 2                              False                                False
# 3                              False                                False
# 4                              False                                False
#
#    MACHINING_PROCESS_Layer 3 Up_True  MACHINING_PROCESS_Prep_True  \
# 0                              False                        False
# 1                              False                         True
# 2                              False                         True
# 3                              False                         True
# 4                              False                         True
#
#    MACHINING_PROCESS_Repositioning_True  MACHINING_PROCESS_Starting_True  \
# 0                                 False                             True
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
#
#    MACHINING_PROCESS_end_True  M1_CURRENT_PROGRAM_NUMBER_1.0_True  \
# 0                       False                                True
# 1                       False                                True
# 2                       False                                True
# 3                       False                                True
# 4                       False                                True
#
#    M1_CURRENT_PROGRAM_NUMBER_4.0_True
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
# [5 rows x 61 columns]
# (25286, 61)
# ['MACHINING_PROCESS_Layer 1 Down', 'MACHINING_PROCESS_Layer 1 Up', 'MACHINING_PROCESS_Layer 2 Down', 'MACHINING_PROCESS_Layer 2 Up', 'MACHINING_PROCESS_Layer 3 Down', 'MACHINING_PROCESS_Layer 3 Up', 'MACHINING_PROCESS_Prep', 'MACHINING_PROCESS_Repositioning', 'MACHINING_PROCESS_Starting', 'MACHINING_PROCESS_end', 'M1_CURRENT_PROGRAM_NUMBER_1.0', 'M1_CURRENT_PROGRAM_NUMBER_4.0']
# Train dataset shape:  (20229, 61)
# ##################################################
# Test dataset shape:  (5057, 61)

# %%
########

###Model implementation

# %%
# !pip install catboost

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
from shutil import get_terminal_size

from sklearn.model_selection import train_test_split, cross_validate, validation_curve
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

import joblib

import os
os.makedirs('models', exist_ok=True)

warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None) # Show all the columns
pd.set_option('display.max_rows', None) # Show all the rows
pd.set_option('max_colwidth', None) # Show all the text in the columns
pd.set_option('display.float_format', lambda x: '%.3f' % x) # Show all the decimals
pd.set_option('display.width', get_terminal_size()[0]) # Get bigger terminal display width

# Load the data
# df = pd.read_csv('dataset/combined_cleaned.csv') # Dropped_list
df = pd.read_csv('aggregated_train_cleaned.csv')

print(df.head())
print(df.dtypes)
#######################################
#### MODEL BUILDING AND EVALUATION ####
#######################################

# 1. Base Models
# 2. Automated Hyperparameter Optimization
# 3. Stacking & Ensemble Learning

# 1. Split Dataset

X = df.drop('TARGET', axis=1)
y = df['TARGET']

# 2.1 without stratify
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)


def base_models(X, y, scoring="roc_auc", cv=5, all_metrics=False):
    print("Base Models....")
    classifiers = [("RF", RandomForestClassifier()),
                   ('XGBoost', XGBClassifier(use_label_encoder=False, eval_metric='logloss')),
                   ]

    if (all_metrics == True):
        for name, classifier in classifiers:
            cv_results = cross_validate(classifier, X, y, cv=cv, scoring=scoring, n_jobs=-1)

            print(f"Accuracy: {round(cv_results['test_accuracy'].mean(), 4)} ({name}) ")
            print(f"F1: {round(cv_results['test_f1'].mean(), 4)} ({name}) ")
            print(f"ROC_AUC: {round(cv_results['test_roc_auc'].mean(), 4)} ({name}) ")

            f = open('Estimators_BaseModels.txt', 'a')
            f.writelines(f"Accuracy: {round(cv_results['test_accuracy'].mean(), 4)} ({name})\n")
            f.writelines(f"F1: {round(cv_results['test_f1'].mean(), 4)} ({name})\n")
            f.writelines(f"ROC_AUC: {round(cv_results['test_roc_auc'].mean(), 4)} ({name})\n")
            f.close()

    else:
        for name, classifier in classifiers:
            cv_results = cross_validate(classifier, X, y, cv=cv, scoring=scoring, n_jobs=-1)

            print(f"{scoring}: {round(cv_results['test_score'].mean(), 4)} ({name}) ")

            f = open('Estimators.txt', 'a')
            f.writelines(f"Score: {round(cv_results['test_score'].mean(), 4)} ({name})\n")
            f.close()

# 1st Approach feed with all data
# base_models(X, y, scoring=["accuracy", "f1", "roc_auc" ], all_metrics=True)

# 2nd Approach feed with train data
base_models(X_train, y_train, scoring=["accuracy", "f1", "roc_auc" ], cv=5, all_metrics=True)

# 2. Automated Hyperparameter Optimization
#knn_params = {"n_neighbors": range(2, 50)}

#cart_params = {'max_depth': range(1, 20),
 #              "min_samples_split": range(2, 30)}

rf_params = {"max_depth": [8, 15, None],
             "max_features": [5, 7, "auto"],
            "min_samples_split": [15, 20],
             "n_estimators": [200, 300]}

xgboost_params = {"learning_rate": [0.1, 0.01],
                  "max_depth": [5, 8],
                  "n_estimators": [100, 200]}

#lightgbm_params = {"learning_rate": [0.01, 0.1],
 #                  "n_estimators": [300, 500]}

classifiers = [("RF", RandomForestClassifier(), rf_params),
                ('XGBoost', XGBClassifier(use_label_encoder=False, eval_metric='logloss'), xgboost_params)
               ]

def hyperparameter_optimization(X, y, classifiers, cv=5, scoring="roc_auc", all_metrics=False):
    print("Hyperparameter Optimization....")
    best_models = {}

    if (all_metrics == True):
        for name, classifier, params in classifiers:
            print(f"########## {name} ##########")
            cv_results = cross_validate(classifier, X, y, cv=cv, scoring=scoring, n_jobs=-1)

            print(f"Accuracy (Before): {round(cv_results['test_accuracy'].mean(), 4)}")
            print(f"F1 (Before): {round(cv_results['test_f1'].mean(), 4)}")
            print(f"ROC_AUC (Before): {round(cv_results['test_roc_auc'].mean(), 4)}")

            gs_best = GridSearchCV(classifier, params, cv=cv, n_jobs=-1, verbose=False).fit(X, y)
            final_model = classifier.set_params(**gs_best.best_params_)

            cv_results = cross_validate(final_model, X, y, cv=cv, scoring=scoring, n_jobs=-1)

            print(f"Accuracy: {round(cv_results['test_accuracy'].mean(), 4)} ({name}) ")
            print(f"F1: {round(cv_results['test_f1'].mean(), 4)} ({name}) ")
            print(f"ROC_AUC: {round(cv_results['test_roc_auc'].mean(), 4)} ({name})")
            print(f"{name} best params: {gs_best.best_params_}", end="\n\n")

            f = open('Estimators_Hyperparameter.txt', 'a')
            f.writelines(f"Accuracy: {round(cv_results['test_accuracy'].mean(), 4)} ({name})\n")
            f.writelines(f"F1: {round(cv_results['test_f1'].mean(), 4)} ({name})\n")
            f.writelines(f"ROC_AUC: {round(cv_results['test_roc_auc'].mean(), 4)} ({name})\n")
            f.writelines(f"{name} best params: {gs_best.best_params_}\n")
            f.close()

            best_models[name] = final_model
    else:
        for name, classifier, params in classifiers:
            print(f"########## {name} ##########")
            cv_results = cross_validate(classifier, X, y, cv=cv, scoring=scoring)
            print(f"{scoring} (Before): {round(cv_results['test_score'].mean(), 4)}")

            gs_best = GridSearchCV(classifier, params, cv=cv, n_jobs=-1, verbose=False).fit(X, y)
            final_model = classifier.set_params(**gs_best.best_params_)

            cv_results = cross_validate(final_model, X, y, cv=cv, scoring=scoring)

            print(f"{scoring} (After): {round(cv_results['test_score'].mean(), 4)}")
            print(f"{name} best params: {gs_best.best_params_}", end="\n\n")

            f = open('Estimators_Hyperparameter.txt', 'a')
            f.writelines(f"{scoring} (After): {round(cv_results['test_score'].mean(), 4)}\n")
            f.writelines(f"{name} best params: {gs_best.best_params_}\n")
            f.close()
            best_models[name] = final_model
    return best_models

# best_models = hyperparameter_optimization(X, y, classifiers=classifiers, cv=5, scoring=["accuracy", "f1", "roc_auc" ], all_metrics=True)

best_models = hyperparameter_optimization(X_train, y_train, classifiers=classifiers, cv=5, scoring=["accuracy", "f1", "roc_auc" ], all_metrics=True)

"""
print(best_models["CART"].fit(X,y).feature_importances_)
print(best_models["RF"].fit(X,y).feature_importances_)
print(best_models["XGBoost"].fit(X,y).feature_importances_)
print(best_models["LightGBM"].fit(X,y).feature_importances_)
"""

################################
### PLOT- FEATURE IMPORTANCE ###
################################

def plot_importance(model, features, name, num=len(X), save=False):
    feature_imp = pd.DataFrame({'Value': model.feature_importances_, 'Feature': features.columns})
    plt.figure(figsize=(10, 10))
    sns.set(font_scale=1)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                                     ascending=False)[0:num])
    plt.title('Features_{}'.format(name))
    plt.tight_layout()
    if save:
        plt.savefig('importances_{}.png'.format(name))
    plt.show()

for model in best_models:
    if model != "KNN":
        final_model = best_models[model].fit(X_train, y_train)
        plot_importance(final_model, X_train, name = model, save=True)
    else:
        pass

##############################
### PLOT- CONFUSION MATRIX ###
##############################
def plot_confusion_matrix(name, y_actual, y_pred, cmap='viridis', save=False):
    cm = confusion_matrix(y_actual, y_pred)

    group_names = ['TN','FP','FN','TP']
    group_counts = ['{0:0.0f}'.format(value) for value in
                    cm.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in
                        cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
            zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot=labels, fmt='', cmap=cmap)
    plt.title('{}'.format(name), fontsize=10)
    if save:
        plt.savefig('confusion_matrix_{}.png'.format(name))
        plt.savefig('confusion_matrix_{}.tiff'.format(name))
    plt.show()

def classification_report_output(name, y_actual, y_pred, target_names=None):

    print(classification_report(y_true=y_actual, y_pred=y_pred,
                                digits=4, target_names=target_names))

    f = open('classification_report.txt', 'a')
    f.writelines(f"########## {name} ##########\n")
    f.writelines(f"{classification_report(y_true=y_actual, y_pred=y_pred, digits=4, target_names=target_names)}\n")
    f.writelines(f"############################\n")
    f.close()

for model in best_models:
    model_fit=best_models[model].fit(X_train, y_train)

    plot_confusion_matrix(name=model,
                          y_actual=y_test,
                          y_pred=model_fit.predict(X_test),
                          save=True)

    # 0 = Unworn, 1 = Worn --> from tool_wear_detection_research.py line 59
    classification_report_output(name=model,
                            y_actual=y_test,
                            y_pred=model_fit.predict(X_test), target_names=["Unworn","Worn"])

def val_curve_params(model, X, y, param_name, param_range, scoring="roc_auc", cv=5):
    train_score, test_score = validation_curve(
        model, X=X, y=y, param_name=param_name, param_range=param_range, scoring=scoring, cv=cv)

    mean_train_score = np.mean(train_score, axis=1)
    mean_test_score = np.mean(test_score, axis=1)

    plt.plot(param_range, mean_train_score,
             label="Training Score", color='b')

    plt.plot(param_range, mean_test_score,
             label="Validation Score", color='g')

    plt.title(f"Validation Curve for {type(model).__name__}")
    plt.xlabel(f"Number of {param_name}")
    plt.ylabel(f"{scoring}")
    plt.tight_layout()
    plt.legend(loc='best')
    plt.savefig(f"Validation Curve for {type(model).__name__}.png")
    plt.show(block=True)

def voting_classifier(best_models, X, y, cv=5):
    print("Voting Classifier...")
    voting_clf = VotingClassifier(estimators=[('RF', best_models["RF"]),
                                              ('XGBoost', best_models["XGBoost"])],
                                  voting='soft').fit(X, y)
    cv_results = cross_validate(voting_clf, X, y, cv=cv, scoring=["accuracy", "f1", "roc_auc"])
    print(f"Accuracy: {cv_results['test_accuracy'].mean()}")
    print(f"F1Score: {cv_results['test_f1'].mean()}")
    print(f"ROC_AUC: {cv_results['test_roc_auc'].mean()}")

    f = open('Ensemble_Results.txt', 'a')

    f.writelines(f"Accuracy: {cv_results['test_accuracy'].mean()}\n")
    f.writelines(f"F1Score: {cv_results['test_f1'].mean()}\n")
    f.writelines(f"ROC_AUC: {cv_results['test_roc_auc'].mean()}\n")
    f.close()

    return voting_clf

voting_clf=voting_classifier(best_models=best_models, X=X_train, y=y_train, cv=5)

classification_report_output(name="Voting Classifier",
                            y_actual=y_test,
                            y_pred=voting_clf.predict(X_test), target_names=["Unworn","Worn"])

plot_confusion_matrix(name="Voting Classifier",
                          y_actual=y_test,
                          y_pred=voting_clf.predict(X_test),
                          save=True)
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp313-cp313-manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.13/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.13/dist-packages (from catboost) (2.1.3)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.13/dist-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.13/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.13/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<4.0,>=0.24->catboost) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp313-cp313-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 9.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10
#    X1_ACTUALPOSITION  X1_ACTUALVELOCITY  X1_ACTUALACCELERATION  \
# 0              0.368              0.487                  0.563
# 1              1.000              0.459                  0.509
# 2              0.316              0.463                  0.607
# 3              1.000              0.459                  0.500
# 4              0.368              0.463                  0.634
#
#    X1_COMMANDPOSITION  X1_COMMANDVELOCITY  X1_COMMANDACCELERATION  \
# 0               0.368               0.480                   0.354
# 1               1.000               0.455                   0.488
# 2               0.316               0.455                   0.488
# 3               1.000               0.455                   0.488
# 4               0.368               0.455                   0.488
#
#    X1_CURRENTFEEDBACK  X1_DCBUSVOLTAGE  X1_OUTPUTCURRENT  X1_OUTPUTVOLTAGE  \
# 0               0.552            0.216             0.636             0.130
# 1               0.476            0.078             0.909             0.010
# 2               0.529            0.192             0.636             0.057
# 3               0.474            0.000             0.727             0.000
# 4               0.564            0.222             0.636             0.024
#
#    X1_OUTPUTPOWER  Y1_ACTUALPOSITION  Y1_ACTUALVELOCITY  \
# 0           0.385              0.206              0.443
# 1           0.377              1.000              0.512
# 2           0.377              0.070              0.504
# 3           0.377              1.000              0.511
# 4           0.377              0.192              0.438
#
#    Y1_ACTUALACCELERATION  Y1_COMMANDPOSITION  Y1_COMMANDVELOCITY  \
# 0                  0.415               0.206               0.447
# 1                  0.520               1.000               0.510
# 2                  0.744               0.071               0.633
# 3                  0.493               1.000               0.510
# 4                  0.401               0.192               0.442
#
#    Y1_COMMANDACCELERATION  Y1_CURRENTFEEDBACK  Y1_DCBUSVOLTAGE  \
# 0                   0.435               0.375            0.392
# 1                   0.488               0.496            0.038
# 2                   1.000               0.492            0.053
# 3                   0.488               0.499            0.000
# 4                   0.488               0.397            0.261
#
#    Y1_OUTPUTCURRENT  Y1_OUTPUTVOLTAGE  Y1_OUTPUTPOWER  Z1_ACTUALPOSITION  \
# 0             0.429             0.238           0.471              0.002
# 1             0.714             0.017           0.376              1.000
# 2             0.500             0.056           0.377              0.024
# 3             0.929             0.000           0.376              1.000
# 4             0.429             0.192           0.440              0.013
#
#    Z1_ACTUALVELOCITY  Z1_ACTUALACCELERATION  Z1_COMMANDPOSITION  \
# 0              0.583                  0.500               0.002
# 1              0.583                  0.562               1.000
# 2              0.625                  0.562               0.024
# 3              0.625                  0.562               1.000
# 4              0.542                  0.438               0.013
#
#    Z1_COMMANDVELOCITY  Z1_COMMANDACCELERATION  Z1_CURRENTFEEDBACK  \
# 0               0.000                   0.000               0.000
# 1               0.000                   0.000               0.000
# 2               0.000                   0.000               0.000
# 3               0.000                   0.000               0.000
# 4               0.000                   0.000               0.000
#
#    Z1_DCBUSVOLTAGE  Z1_OUTPUTCURRENT  Z1_OUTPUTVOLTAGE  S1_ACTUALPOSITION  \
# 0            0.000             0.000             0.000              0.318
# 1            0.000             0.000             0.000              0.284
# 2            0.000             0.000             0.000              0.072
# 3            0.000             0.000             0.000              0.230
# 4            0.000             0.000             0.000              0.067
#
#    S1_ACTUALVELOCITY  S1_ACTUALACCELERATION  S1_COMMANDPOSITION  \
# 0              0.993                  0.522               0.318
# 1              0.001                  0.498               0.284
# 2              0.991                  0.479               0.072
# 3              0.001                  0.495               0.230
# 4              0.993                  0.504               0.067
#
#    S1_COMMANDVELOCITY  S1_COMMANDACCELERATION  S1_CURRENTFEEDBACK  \
# 0               1.000                   0.000               0.388
# 1               0.000                   0.200               0.121
# 2               1.000                   0.000               0.390
# 3               0.000                   0.200               0.089
# 4               1.000                   0.400               0.382
#
#    S1_DCBUSVOLTAGE  S1_OUTPUTCURRENT  S1_OUTPUTVOLTAGE  S1_OUTPUTPOWER  \
# 0            0.340             0.739             0.892           0.347
# 1            0.000             0.942             0.000           0.006
# 2            0.369             0.739             0.892           0.376
# 3            0.000             0.971             0.000           0.006
# 4            0.299             0.739             0.885           0.303
#
#    S1_SYSTEMINERTIA  M1_SEQUENCE_NUMBER  M1_CURRENT_FEEDRATE  FEEDRATE  \
# 0             0.000               0.911                0.000     0.000
# 1             0.000               0.000                1.000     1.000
# 2             0.000               0.148                0.064     0.176
# 3             0.000               0.015                1.000     1.000
# 4             0.000               0.015                0.000     0.000
#
#    CLAMP_PRESSURE  TARGET  MACHINING_PROCESS_Layer 1 Down_True  \
# 0           1.000       1                                False
# 1           0.333       1                                False
# 2           0.333       1                                False
# 3           1.000       0                                False
# 4           0.000       1                                 True
#
#    MACHINING_PROCESS_Layer 1 Up_True  MACHINING_PROCESS_Layer 2 Down_True  \
# 0                              False                                False
# 1                              False                                False
# 2                              False                                False
# 3                               True                                False
# 4                              False                                False
#
#    MACHINING_PROCESS_Layer 2 Up_True  MACHINING_PROCESS_Layer 3 Down_True  \
# 0                              False                                False
# 1                              False                                False
# 2                              False                                False
# 3                              False                                False
# 4                              False                                False
#
#    MACHINING_PROCESS_Layer 3 Up_True  MACHINING_PROCESS_Prep_True  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# 4                              False                        False
#
#    MACHINING_PROCESS_Repositioning_True  MACHINING_PROCESS_Starting_True  \
# 0                                 False                            False
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
#
#    MACHINING_PROCESS_end_True  M1_CURRENT_PROGRAM_NUMBER_1.0_True  \
# 0                       False                                True
# 1                       False                                True
# 2                       False                                True
# 3                       False                                True
# 4                       False                                True
#
#    M1_CURRENT_PROGRAM_NUMBER_4.0_True
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# X1_ACTUALPOSITION                       float64
# X1_ACTUALVELOCITY                       float64
# X1_ACTUALACCELERATION                   float64
# X1_COMMANDPOSITION                      float64
# X1_COMMANDVELOCITY                      float64
# X1_COMMANDACCELERATION                  float64
# X1_CURRENTFEEDBACK                      float64
# X1_DCBUSVOLTAGE                         float64
# X1_OUTPUTCURRENT                        float64
# X1_OUTPUTVOLTAGE                        float64
# X1_OUTPUTPOWER                          float64
# Y1_ACTUALPOSITION                       float64
# Y1_ACTUALVELOCITY                       float64
# Y1_ACTUALACCELERATION                   float64
# Y1_COMMANDPOSITION                      float64
# Y1_COMMANDVELOCITY                      float64
# Y1_COMMANDACCELERATION                  float64
# Y1_CURRENTFEEDBACK                      float64
# Y1_DCBUSVOLTAGE                         float64
# Y1_OUTPUTCURRENT                        float64
# Y1_OUTPUTVOLTAGE                        float64
# Y1_OUTPUTPOWER                          float64
# Z1_ACTUALPOSITION                       float64
# Z1_ACTUALVELOCITY                       float64
# Z1_ACTUALACCELERATION                   float64
# Z1_COMMANDPOSITION                      float64
# Z1_COMMANDVELOCITY                      float64
# Z1_COMMANDACCELERATION                  float64
# Z1_CURRENTFEEDBACK                      float64
# Z1_DCBUSVOLTAGE                         float64
# Z1_OUTPUTCURRENT                        float64
# Z1_OUTPUTVOLTAGE                        float64
# S1_ACTUALPOSITION                       float64
# S1_ACTUALVELOCITY                       float64
# S1_ACTUALACCELERATION                   float64
# S1_COMMANDPOSITION                      float64
# S1_COMMANDVELOCITY                      float64
# S1_COMMANDACCELERATION                  float64
# S1_CURRENTFEEDBACK                      float64
# S1_DCBUSVOLTAGE                         float64
# S1_OUTPUTCURRENT                        float64
# S1_OUTPUTVOLTAGE                        float64
# S1_OUTPUTPOWER                          float64
# S1_SYSTEMINERTIA                        float64
# M1_SEQUENCE_NUMBER                      float64
# M1_CURRENT_FEEDRATE                     float64
# FEEDRATE                                float64
# CLAMP_PRESSURE                          float64
# TARGET                                    int64
# MACHINING_PROCESS_Layer 1 Down_True        bool
# MACHINING_PROCESS_Layer 1 Up_True          bool
# MACHINING_PROCESS_Layer 2 Down_True        bool
# MACHINING_PROCESS_Layer 2 Up_True          bool
# MACHINING_PROCESS_Layer 3 Down_True        bool
# MACHINING_PROCESS_Layer 3 Up_True          bool
# MACHINING_PROCESS_Prep_True                bool
# MACHINING_PROCESS_Repositioning_True       bool
# MACHINING_PROCESS_Starting_True            bool
# MACHINING_PROCESS_end_True                 bool
# M1_CURRENT_PROGRAM_NUMBER_1.0_True         bool
# M1_CURRENT_PROGRAM_NUMBER_4.0_True         bool
# dtype: object
# Base Models....
# Accuracy: 0.9923 (RF)
# F1: 0.9927 (RF)
# ROC_AUC: 0.9998 (RF)
# Accuracy: 0.9941 (XGBoost)
# F1: 0.9944 (XGBoost)
# ROC_AUC: 0.9997 (XGBoost)
# Hyperparameter Optimization....
# ########## RF ##########
# Accuracy (Before): 0.9927
# F1 (Before): 0.9931
# ROC_AUC (Before): 0.9998
# Accuracy: 0.9912 (RF)
# F1: 0.9916 (RF)
# ROC_AUC: 0.9998 (RF)
# RF best params: {'max_depth': None, 'max_features': 7, 'min_samples_split': 15, 'n_estimators': 300}
#
# ########## XGBoost ##########
# Accuracy (Before): 0.9941
# F1 (Before): 0.9944
# ROC_AUC (Before): 0.9997
# Accuracy: 0.9947 (XGBoost)
# F1: 0.995 (XGBoost)
# ROC_AUC: 0.9998 (XGBoost)
# XGBoost best params: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#       Unworn     0.9963    0.9891    0.9927      1918
#         Worn     0.9902    0.9967    0.9934      2128
#
#     accuracy                         0.9931      4046
#    macro avg     0.9933    0.9929    0.9931      4046
# weighted avg     0.9931    0.9931    0.9931      4046
#               precision    recall  f1-score   support
#
#       Unworn     0.9953    0.9948    0.9950      1918
#         Worn     0.9953    0.9958    0.9955      2128
#
#     accuracy                         0.9953      4046
#    macro avg     0.9953    0.9953    0.9953      4046
# weighted avg     0.9953    0.9953    0.9953      4046
#
# Voting Classifier...
# Accuracy: 0.9945004320791773
# F1Score: 0.9947747696104317
# ROC_AUC: 0.9998774716715989
#               precision    recall  f1-score   support
#
#       Unworn     0.9948    0.9953    0.9950      1918
#         Worn     0.9958    0.9953    0.9955      2128
#
#     accuracy                         0.9953      4046
#    macro avg     0.9953    0.9953    0.9953      4046
# weighted avg     0.9953    0.9953    0.9953      4046

# %%
###################
### Save Models and Figures###
###################

joblib.dump(best_models["XGBoost"], "models/xgboost_model.pkl")
joblib.dump(best_models["RF"], "models/rf_model.pkl")
#joblib.dump(best_models["LightGBM"], "models/lightgbm_model.pkl")
joblib.dump(voting_clf, "models/voting_clf.pkl")
# Out:
# ['models/voting_clf.pkl']

# %%
import os
os.makedirs('images', exist_ok=True)

# %%
plt.figure(figsize=(6, 4))

df["TARGET"].value_counts().plot(kind="bar")

plt.title("Distribution of Tool Condition")
plt.xlabel("Tool Condition")
plt.ylabel("Number of Samples")

plt.xticks(rotation=0)
plt.tight_layout()

plt.savefig('images/target_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(14, 10))

plt.imshow(df_corr, aspect="auto")
plt.colorbar()

plt.xticks(range(len(df_corr.columns)), df_corr.columns, rotation=90)
plt.yticks(range(len(df_corr.columns)), df_corr.columns)

plt.title("Correlation Matrix")
plt.tight_layout()

plt.savefig('images/correlation_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Recompute numeric columns fresh and only keep ones that still exist in df
numeric_columns = df.select_dtypes(include=np.number).columns.tolist()
features = [column for column in numeric_columns if column != "TARGET" and column in df.columns]

for column in features:

    plt.figure(figsize=(7, 4))

    df.boxplot(column=column, by="TARGET")

    plt.title(f"{column}: Worn vs Unworn")
    plt.suptitle("")

    plt.xlabel("Tool Condition")
    plt.ylabel(column)

    plt.tight_layout()

    safe_name = column.replace("/", "_")
    plt.savefig(f'images/boxplot_{safe_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
import shutil
shutil.make_archive('cnc_images', 'zip', 'images')

from google.colab import files
files.download('cnc_images.zip')
